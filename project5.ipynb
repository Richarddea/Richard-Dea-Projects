# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 5:  Web Scraping
# ### Finding Underpriced RVs on Craigslist
#
# ![](https://snag.gy/WrdUMx.jpg)

# %% [markdown]
# In this project we will be practicing our web scraping skills.  You can use Scrapy or Python requests in order to complete this project.  It may be helpful to write some prototype code in this notebook to test your assumptions, then move it into a Python file that can be run from the command line.
#
# > In order to run code from the command line, instead of the notebook, you just need to save your code to a file (with a .py extension), and run it using the Python interpreter:<br><br>
# > `python my_file.py`
#
# You will be building a process to scrape a single category of search results on Craigslist, that can easily be applied to other categories by changing the search terms.  The main goal is to be able to target and scrape a single page given a set of parameters.
#
# **If you use Scrapy, provide your code in a folder.**

# %% [markdown]
# ## Import your libraries for scrapy / requests / pandas / numpy / etc
# Setup whichever libraries you need. Review past material for reference.

# %%
import pandas as pd
from scrapy.selector import Selector
from scrapy.http import HtmlResponse
import requests
from bs4 import BeautifulSoup

CL = requests.get("http://lasvegas.craigslist.org/search/sss?query=rv")
HTML = CL.text  
HTML[0:150]
# Out:
# u'\ufeff<!DOCTYPE html>\n\n<html class="no-js"><head>\n    <title>las vegas for sale &quot;rv&quot; - craigslist</title>\n\n    <meta name="description" content="'

# %%
http://www.imdb.com/title/tt0068646/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2398042102&pf_rd_r=0R5QM449C7SZSE5HEFB0&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_2
http://www.imdb.com/title/tt0111161/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2398042102&pf_rd_r=0R5QM449C7SZSE5HEFB0&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_tt_1

# %%
print HTML
# Out:
# ﻿<!DOCTYPE html>
#
# <html class="no-js"><head>
#     <title>las vegas for sale &quot;rv&quot; - craigslist</title>
#
#     <meta name="description" content="las vegas for sale &quot;rv&quot; - craigslist">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#     <link rel="canonical" href="https://lasvegas.craigslist.org/search/sss">
#     <link rel="alternate" type="application/rss+xml" href="https://lasvegas.craigslist.org/search/sss?format=rss&amp;query=rv" title="RSS feed for craigslist | las vegas for sale &quot;rv&quot; - craigslist ">
#
#     <link rel="next" href="https://lasvegas.craigslist.org/search/sss?s=100&amp;query=rv">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=c27e72792da0a56cfce19f5d49f8838b">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=af75b8cc1e45fb421a5858821aadf330">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=31607a98a2cb3fba2c70e3e66ecb4440">
#     <link rel="prefetch" href="//www.craigslist.org/js/postings-concat.min.js?v=6792206d97a3fd6d2c0513af0c87af3d">
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=52966d0fad2afe8dd918e5f48abb0db3">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=c9937ed03fbb57f185493cd8c283efeb">
# <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=e1c93c9e4b8d31fc183c0dff0c70e0b7">
# <!--[if IE]>
#     <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">
# <![endif]-->
#
#         <script type="text/javascript"><!--
# var areaCountry = "US";
# var areaID = "26";
# var areaRegion = "NV";
# var catAbb = "sss";
# var countOfTotalText = "image {count} of {total}";
# var currencySymbol = "&#x0024;";
# var defaultView = "grid";
# var expiredFavIDs = null;
# var imageHost = "https://images.craigslist.org";
# var lessInfoText = "less info";
# var maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";
# var maxResults = 2500;
# var noImageText = "no image";
# var pID = null;
# var purveyorCategories = {"owner":"sso","dealer":"ssq","all":"sss"};
# var sectionAbb = "sss";
# var sectionBase = "sss";
# var showInfoText = "show info";
# var showMapTabs = 1;
# var showingBanished = 0;
# var showingFavorites = 0;
# var starHint = "save this post in your favorites list";
# var subarea = null;
# var zoomToPosting = null;
# --></script>
#
#     <!--[if lt IE 9]>
# <script src="//www.craigslist.org/js/html5shiv.min.js?v=096822b653643ed1af3136947e4ea79a" type="text/javascript" ></script>
#
# <script src="//www.craigslist.org/js/respond-fork.min.js?v=d7e1cb0d97ee0c0c9d84a7d4f1d03469" type="text/javascript" ></script>
#
# <![endif]-->
# <!--[if lte IE 7]>
# <script src="//www.craigslist.org/js/json2.min.js?v=178d4ad319e0e0b4a451b15e49b71bec" type="text/javascript" ></script>
#
# <![endif]-->
# </head>
# <body class="search en">
#     <script type="text/javascript"><!--
#     function C(k){return(document.cookie.match('(^|; )'+k+'=([^;]*)')||0)[2]}
#     var pagetype, pagemode;
#     (function(){
#         var h = document.documentElement;
#         h.className = h.className.replace('no-js', 'js');
#         var b = document.body;
#         var bodyClassList = b.className.split(/\s+/);;
#         pagetype = bodyClassList[0]; // dangerous assumption
#         var fmt = C('cl_fmt');
#         if ( fmt === 'regular' || fmt === 'mobile' ) {
#             pagemode = fmt;
#         } else if (screen.width <= 480) {
#             pagemode = 'mobile';
#         } else {
#             pagemode = 'regular';
#         }
#         pagemode = pagemode === 'mobile' ? 'mobile' : 'desktop';
#         bodyClassList.push(pagemode);
#         if (C('hidesearch') === '1' && pagemode !== 'mobile') {
#             bodyClassList.push('hide-search');
#         }
#         var width = window.innerWidth || document.documentElement.clientWidth;
#         if (width > 1000) { bodyClassList.push('w1024'); }
#         if (typeof window.sectionBase !== 'undefined') {
#             var mode = (decodeURIComponent(C('cl_tocmode') || '').match(new RegExp(window.sectionBase + ':([^,]+)', 'i')) || {})[1] || window.defaultView;
#             if (mode) {
#                 bodyClassList.push(mode);
#             }
#         }
#         b.className = bodyClassList.join(' ');
#     }());
# --></script>
#
#
#     <section id="pagecontainer">
#         <div class="bglogo"></div>
#         <header class="global-header">
#    <a class="header-logo" href="/">CL</a>
#
#     <nav class="breadcrumbs-container">
# <form id="breadcrumbform" class="breadcrumbs-form" method="get" action="/search/sss" data-action="/search/###/sss">
#     <input type="hidden" name="query" value="rv">
#     <ul class="breadcrumbs">
#         <li class="crumb area">
#
#             <span class="no-js">
#                 <a href="/">las vegas</a>
#             </span>
#                 <select name="areaAbb" id="areaAbb" class="js-only">
#                     <option value="lasvegas">las vegas</option>
#                         <option value="bakersfield">bakersfield</option>
#                         <option value="flagstaff">flagstaff</option>
#                         <option value="imperial">imperial co</option>
#                         <option value="inlandempire">inland empire</option>
#                         <option value="losangeles">los angeles</option>
#                         <option value="mohave">mohave co</option>
#                         <option value="orangecounty">orange co</option>
#                         <option value="palmsprings">palm springs</option>
#                         <option value="prescott">prescott</option>
#                         <option value="stgeorge">st george</option>
#                         <option value="visalia">visalia-tulare</option>
#                 </select>
#             <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb section">
#                     <select name="catAbb" id="catAbb">
#                         <option value="ccc">community</option>
#                         <option value="eee">events</option>
#                         <option value="sss" selected>for sale</option>
#                         <option value="ggg">gigs</option>
#                         <option value="hhh">housing</option>
#                         <option value="jjj">jobs</option>
#                         <option value="ppp">personals</option>
#                         <option value="rrr">resumes</option>
#                         <option value="bbb">services</option>
#                     </select>
#                 <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb category">
#             <select id="subcatAbb" class="js-only">
#                 <option value="sss">all</option>
#                     <option value="ata">antiques</option>
#                     <option value="ppa">appliances</option>
#                     <option value="ara">arts+crafts</option>
#                     <option value="sna">atvs/utvs/snow</option>
#                     <option value="pta">auto parts</option>
#                     <option value="wta">auto wheels &amp; tires</option>
#                     <option value="baa">baby+kids</option>
#                     <option value="bar">barter</option>
#                     <option value="haa">beauty+hlth</option>
#                     <option value="bip">bike parts</option>
#                     <option value="bia">bikes</option>
#                     <option value="bpa">boat parts</option>
#                     <option value="boo">boats</option>
#                     <option value="bka">books</option>
#                     <option value="bfa">business</option>
#                     <option value="cta">cars+trucks</option>
#                     <option value="ema">cds/dvd/vhs</option>
#                     <option value="moa">cell phones</option>
#                     <option value="cla">clothes+acc</option>
#                     <option value="cba">collectibles</option>
#                     <option value="syp">computer parts</option>
#                     <option value="sya">computers</option>
#                     <option value="ela">electronics</option>
#                     <option value="gra">farm+garden</option>
#                     <option value="zip">free stuff</option>
#                     <option value="fua">furniture</option>
#                     <option value="gms">garage sales</option>
#                     <option value="foa">general</option>
#                     <option value="hva">heavy equipment</option>
#                     <option value="hsa">household</option>
#                     <option value="jwa">jewelry</option>
#                     <option value="maa">materials</option>
#                     <option value="mpa">motorcycle parts</option>
#                     <option value="mca">motorcycles</option>
#                     <option value="msa">music instr</option>
#                     <option value="pha">photo+video</option>
#                     <option value="rva">RVs</option>
#                     <option value="sga">sporting</option>
#                     <option value="tia">tickets</option>
#                     <option value="tla">tools</option>
#                     <option value="taa">toys+games</option>
#                     <option value="tra">trailers</option>
#                     <option value="vga">video gaming</option>
#                     <option value="waa">wanted</option>
#             </select><span class="no-js">for sale</span>
#             <span class="breadcrumb-arrow">&gt;</span>
#         </li>
#         <li class="crumb no-js">
#             <input type="submit" value="go">
#         </li>
#     </ul>
# </form>
#     </nav>
#
# <div class="userlinks">
#     <ul class="user-actions">
#         <li class="user post">
#             <a href="https://post.craigslist.org/c/lvg">post</a>
#         </li>
#         <li class="user account">
#             <a href="https://accounts.craigslist.org/login/home">account</a>
#         </li>
#     </ul>
#     <ul class="user-favs-discards">
#         <li class="user">
#             <div class="favorites">
#                 <a href="#" class="favlink"><span class="icon icon-star fav" aria-hidden="true"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>
#             </div>
#         </li>
#         <li class="user discards">
#           <form class="unfavform js-only" method="POST" action="/favorites">
#             <div class="to-banish-page">
#               <input type="hidden" class="lastLink" name="lastLink" value="//lasvegas.craigslist.org/search/sss?query=rv">
#               <input type="hidden" class="lastTitle" name="lastTitle" value="las vegas for sale &quot;rv&quot; - craigslist">
#               <input type="hidden" class="unfaves" name="fl">
#               <input type="hidden" name="uf" value="1">
#               <a href="#" class="to-banish-page-link">
#                 <span class="icon icon-trash red" aria-hidden="true"></span>
#                 <span class="banished_count">0</span>
#                 <span class="discards-label"> hidden</span>
#               </a>
#             </div>
#           </form>
#         </li>
#     </ul>
# </div>
# </header>
#
#
#         <form id="searchform" class="search-form" action="/search/sss"  >
#
#             <div class="querybox">
#
#                 <div class="form-tab js-only"><span class="search-open" title="hide search">&laquo;</span><span class="search-closed" title="show search">&raquo;</span></div>
#
#                 <input type="text" placeholder="search for sale" name="query"
#                     id="query" value="rv" autocorrect="off"
#                     autocapitalize="off" autocomplete="off" data-autocomplete="search"
#                     class="flatinput ui-autocomplete-input">
#
#                 <button type="submit" class="searchbtn">
#                     <span class="icon icon-search" aria-hidden="true"></span>
#                     <span class="screen-reader-text">press to search craigslist</span>
#                 </button>
#                 <div class="savealert">
#                             <a class="saveme" data-action="save"  href="https://accounts.craigslist.org/login?rt=L&amp;rp=%2Fsavesearch%2Fsave%3FURL%3Dhttps%253A%252F%252Flasvegas%252Ecraigslist%252Eorg%252Fsearch%252Fsss%253Fquery%253Drv"  title="save this search" >save search</a>
#                         </div>
#             </div>
#
#             <div class="search-options-container">
#     <h2 class="search-options-header linklike">
#         <div class="icon icon-toggle-gear" aria-hidden="true"></div>
#         options<span class="options-close">close</span>
#     </h2>
#     <input id="excats" type="hidden" name="excats">
#     <div class="search-options">
#         <div class="searchgroup categories">
#             <div class="cattitle">
#                   <a href="/search/sss" title="clear all search parameters" class="reset">for sale</a>
#             </div>
#
# <ul class="maincats">
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="124,168" class="catcheck multi_checkbox"
#                data-abb="rva" id="cat_rva"
#                checked="checked">
#         <a href="/search/rva?query=rv" class="category">recreational vehicles</a> <span class="count">1797</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="5,179" class="catcheck multi_checkbox"
#                data-abb="foa" id="cat_foa"
#                checked="checked">
#         <a href="/search/foa?query=rv" class="category">general for sale</a> <span class="count">162</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="20,190" class="catcheck multi_checkbox"
#                data-abb="waa" id="cat_waa"
#                checked="checked">
#         <a href="/search/waa?query=rv" class="category">wanted</a> <span class="count">121</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="145,146" class="catcheck multi_checkbox"
#                data-abb="cta" id="cat_cta"
#                checked="checked">
#         <a href="/search/cta?query=rv" class="category">cars &amp; trucks</a> <span class="count">102</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="122,163" class="catcheck multi_checkbox"
#                data-abb="pta" id="cat_pta"
#                checked="checked">
#         <a href="/search/pta?query=rv" class="category">auto parts</a> <span class="count">61</span>
#     </li>
#
#         <li class="morecats js-only closed">
#
#             <span class="linklike closed"><span class="plusminus">+</span>show 39 more</span>
#             <span class="linklike open"><span class="plusminus">&ndash;</span>hide 39 more</span>
#
#             <span class="count">310</span>
#     </li>
# </ul>
#
#     <ul class="othercats closed">
#
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="205,206" class="catcheck multi_checkbox"
#                data-abb="tra" id="cat_tra"
#                checked="checked">
#         <a href="/search/tra?query=rv" class="category">trailers</a> <span class="count">49</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="133,178" class="catcheck multi_checkbox"
#                data-abb="gra" id="cat_gra"
#                checked="checked">
#         <a href="/search/gra?query=rv" class="category">farm &amp; garden</a> <span class="count">38</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="191,192" class="catcheck multi_checkbox"
#                data-abb="sna" id="cat_sna"
#                checked="checked">
#         <a href="/search/sna?query=rv" class="category">atvs, utvs, snowmobiles</a> <span class="count">26</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="42" class="catcheck multi_checkbox"
#                data-abb="bar" id="cat_bar"
#                checked="checked">
#         <a href="/search/bar?query=rv" class="category">barter</a> <span class="count">20</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="119,164" class="catcheck multi_checkbox"
#                data-abb="boo" id="cat_boo"
#                checked="checked">
#         <a href="/search/boo?query=rv" class="category">boats</a> <span class="count">19</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="134,174" class="catcheck multi_checkbox"
#                data-abb="bfa" id="cat_bfa"
#                checked="checked">
#         <a href="/search/bfa?query=rv" class="category">business</a> <span class="count">16</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="96,167" class="catcheck multi_checkbox"
#                data-abb="ela" id="cat_ela"
#                checked="checked">
#         <a href="/search/ela?query=rv" class="category">electronics</a> <span class="count">16</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="149,162" class="catcheck multi_checkbox"
#                data-abb="ppa" id="cat_ppa"
#                checked="checked">
#         <a href="/search/ppa?query=rv" class="category">appliances</a> <span class="count">15</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="97,181" class="catcheck multi_checkbox"
#                data-abb="hsa" id="cat_hsa"
#                checked="checked">
#         <a href="/search/hsa?query=rv" class="category">household items</a> <span class="count">13</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="118,187" class="catcheck multi_checkbox"
#                data-abb="tla" id="cat_tla"
#                checked="checked">
#         <a href="/search/tla?query=rv" class="category">tools</a> <span class="count">11</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="141,142" class="catcheck multi_checkbox"
#                data-abb="fua" id="cat_fua"
#                checked="checked">
#         <a href="/search/fua?query=rv" class="category">furniture</a> <span class="count">11</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="203,204" class="catcheck multi_checkbox"
#                data-abb="wta" id="cat_wta"
#                checked="checked">
#         <a href="/search/wta?query=rv" class="category">auto wheels &amp; tires</a> <span class="count">11</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="69,160" class="catcheck multi_checkbox"
#                data-abb="mca" id="cat_mca"
#                checked="checked">
#         <a href="/search/mca?query=rv" class="category">motorcycles/scooters</a> <span class="count">9</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="44,161" class="catcheck multi_checkbox"
#                data-abb="tia" id="cat_tia"
#                checked="checked">
#         <a href="/search/tia?query=rv" class="category">tickets</a> <span class="count">9</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="193,194" class="catcheck multi_checkbox"
#                data-abb="hva" id="cat_hva"
#                checked="checked">
#         <a href="/search/hva?query=rv" class="category">heavy equipment</a> <span class="count">8</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="201,202" class="catcheck multi_checkbox"
#                data-abb="bpa" id="cat_bpa"
#                checked="checked">
#         <a href="/search/bpa?query=rv" class="category">boat parts &amp; accessories</a> <span class="count">6</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="93,186" class="catcheck multi_checkbox"
#                data-abb="sga" id="cat_sga"
#                checked="checked">
#         <a href="/search/sga?query=rv" class="category">sporting goods</a> <span class="count">5</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="68,172" class="catcheck multi_checkbox"
#                data-abb="bia" id="cat_bia"
#                checked="checked">
#         <a href="/search/bia?query=rv" class="category">bicycles</a> <span class="count">5</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="73" class="catcheck multi_checkbox"
#                data-abb="gms" id="cat_gms"
#                checked="checked">
#         <a href="/search/gms?query=rv" class="category">garage &amp; moving sales</a> <span class="count">4</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="150,169" class="catcheck multi_checkbox"
#                data-abb="ata" id="cat_ata"
#                checked="checked">
#         <a href="/search/ata?query=rv" class="category">antiques</a> <span class="count">4</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="195,196" class="catcheck multi_checkbox"
#                data-abb="mpa" id="cat_mpa"
#                checked="checked">
#         <a href="/search/mpa?query=rv" class="category">motorcycle parts &amp; accessories</a> <span class="count">3</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="135,170" class="catcheck multi_checkbox"
#                data-abb="ara" id="cat_ara"
#                checked="checked">
#         <a href="/search/ara?query=rv" class="category">arts &amp; crafts</a> <span class="count">2</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="136,183" class="catcheck multi_checkbox"
#                data-abb="maa" id="cat_maa"
#                checked="checked">
#         <a href="/search/maa?query=rv" class="category">materials</a> <span class="count">2</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="92,173" class="catcheck multi_checkbox"
#                data-abb="bka" id="cat_bka"
#                checked="checked">
#         <a href="/search/bka?query=rv" class="category">books &amp; magazines</a> <span class="count">2</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="151,189" class="catcheck multi_checkbox"
#                data-abb="vga" id="cat_vga"
#                checked="checked">
#         <a href="/search/vga?query=rv" class="category">video gaming</a> <span class="count">1</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="152,180" class="catcheck multi_checkbox"
#                data-abb="haa" id="cat_haa"
#                checked="checked">
#         <a href="/search/haa?query=rv" class="category">health and beauty</a> <span class="count">1</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="137,185" class="catcheck multi_checkbox"
#                data-abb="pha" id="cat_pha"
#                checked="checked">
#         <a href="/search/pha?query=rv" class="category">photo/video</a> <span class="count">1</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="101" class="catcheck multi_checkbox"
#                data-abb="zip" id="cat_zip"
#                checked="checked">
#         <a href="/search/zip?query=rv" class="category">free stuff</a> <span class="count">1</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="98,184" class="catcheck multi_checkbox"
#                data-abb="msa" id="cat_msa"
#                checked="checked">
#         <a href="/search/msa?query=rv" class="category">musical instruments</a> <span class="count">1</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="95,177" class="catcheck multi_checkbox"
#                data-abb="cba" id="cat_cba"
#                checked="checked">
#         <a href="/search/cba?query=rv" class="category">collectibles</a> <span class="count">1</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="132,188" class="catcheck multi_checkbox"
#                data-abb="taa" id="cat_taa"
#                checked="checked">
#         <a href="/search/taa?query=rv" class="category">toys &amp; games</a> <span class="count">0</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="94,176" class="catcheck multi_checkbox"
#                data-abb="cla" id="cat_cla"
#                checked="checked">
#         <a href="/search/cla?query=rv" class="category">clothing &amp; accessories</a> <span class="count">0</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="120,182" class="catcheck multi_checkbox"
#                data-abb="jwa" id="cat_jwa"
#                checked="checked">
#         <a href="/search/jwa?query=rv" class="category">jewelry</a> <span class="count">0</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="197,198" class="catcheck multi_checkbox"
#                data-abb="bip" id="cat_bip"
#                checked="checked">
#         <a href="/search/bip?query=rv" class="category">bicycle parts</a> <span class="count">0</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="199,200" class="catcheck multi_checkbox"
#                data-abb="syp" id="cat_syp"
#                checked="checked">
#         <a href="/search/syp?query=rv" class="category">computer parts</a> <span class="count">0</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="107,171" class="catcheck multi_checkbox"
#                data-abb="baa" id="cat_baa"
#                checked="checked">
#         <a href="/search/baa?query=rv" class="category">baby &amp; kid stuff</a> <span class="count">0</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="7,166" class="catcheck multi_checkbox"
#                data-abb="sya" id="cat_sya"
#                checked="checked">
#         <a href="/search/sya?query=rv" class="category">computers</a> <span class="count">0</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="117,175" class="catcheck multi_checkbox"
#                data-abb="ema" id="cat_ema"
#                checked="checked">
#         <a href="/search/ema?query=rv" class="category">cds / dvds / vhs</a> <span class="count">0</span>
#     </li>
#     <li>
#            <input type="checkbox" name="cat_id"
#                value="153,165" class="catcheck multi_checkbox"
#                data-abb="moa" id="cat_moa"
#                checked="checked">
#         <a href="/search/moa?query=rv" class="category">cell phones</a> <span class="count">0</span>
#     </li>
# </ul>
#
#         <li class="selectall js-only checked"><label>
#             <input type="checkbox" class="catcheck selectallcb" checked="checked">
#             <span class="all linklike">select all</span>
#             <span class="none linklike">deselect all</span>
#         </label></li>
#
#
#
#         </div>
#         <input type="hidden" name="userid" value="" />
#
#                 <ul class="searchgroup buttongroup purveyor">
#                     <li class="button sel">
#                         <a href="" data-val="all">all</a>
#                     </li><li class="button ">
#                         <a href="" data-val="owner"> owner</a>
#                     </li><li class="button ">
#                         <a href="" data-val="dealer">dealer</a>
#                     </li>
#                 </ul>
#
#
#
#
#         <div class="searchgroup">
#             <ul><li><label class="srchType"><input type="checkbox" name="srchType" class="autosubmit" value="T" >search titles only</label></li><li><label class="hasPic"><input type="checkbox" name="hasPic" class="autosubmit" value="1" >has image</label></li><li><label class="postedToday"><input type="checkbox" name="postedToday" class="autosubmit" value="1" >posted today</label></li><li><label class="searchNearby"><input type="checkbox" name="searchNearby" class="autosubmit" value="1" >include nearby areas</label></li></ul>
#
#             <ul class="js-only nearbyAreas ">
#                     <li class="nearbyZone nearbyZone_1">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_7"
#                           value="63"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         bakersfield, CA <small>(bak)</small>
#                       </label>
#                     </li>
#                     <li class="">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_5"
#                           value="244"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         flagstaff / sedona <small>(flg)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_2">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_15"
#                           value="43"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         fresno / madera <small>(fre)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_2">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_12"
#                           value="709"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         hanford-corcoran <small>(hnf)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_1">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_6"
#                           value="455"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         imperial county <small>(imp)</small>
#                       </label>
#                     </li>
#                     <li class="">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_4"
#                           value="104"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         inland empire, CA <small>(inl)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_1">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_9"
#                           value="7"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         los angeles <small>(lax)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_3">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_19"
#                           value="285"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         merced, CA <small>(mer)</small>
#                       </label>
#                     </li>
#                     <li class="">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_0"
#                           value="565"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         mohave county <small>(mhv)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_1">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_8"
#                           value="103"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         orange county, CA <small>(orc)</small>
#                       </label>
#                     </li>
#                     <li class="">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_2"
#                           value="209"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         palm springs, CA <small>(psp)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_2">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_13"
#                           value="18"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         phoenix, AZ <small>(phx)</small>
#                       </label>
#                     </li>
#                     <li class="">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_3"
#                           value="419"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         prescott, AZ <small>(prc)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_2">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_16"
#                           value="8"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         san diego <small>(sdo)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_3">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_18"
#                           value="62"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         santa barbara <small>(sba)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_3">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_20"
#                           value="710"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         santa maria, CA <small>(smx)</small>
#                       </label>
#                     </li>
#                     <li class="">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_1"
#                           value="352"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         st george, UT <small>(stg)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_2">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_17"
#                           value="181"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         tijuana, MX <small>(tij)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_2">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_14"
#                           value="208"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         ventura county <small>(oxr)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_1">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_10"
#                           value="346"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         visalia-tulare <small>(vis)</small>
#                       </label>
#                     </li>
#                     <li class="nearbyZone nearbyZone_1">
#                       <label class="nearby">
#                         <input
#                           type="checkbox"
#                           class="use-id nearbyArea"
#                           name="nearbyArea"
#                           id="nearbyArea_11"
#                           value="370"
#
#                            disabled=&quot;disabled&quot;
#                         />
#                         yuma, AZ <small>(yum)</small>
#                       </label>
#                     </li>
#
#                     <li>
#                       <span class="nextNearbyZone linklike" data-zone="1">
#                         + show <span id="nearbyNumber">21</span> more...
#                       </span>
#                     </li>
#             </ul>
#
#         </div>
#
#             <div class="searchgroup">
#                 <span class="searchfieldlabel">miles from zip</span>
#                 <input type="number" max="200" min="0" size="3" inputmode="numeric"
#                     class="flatinput searchInput search_distance" placeholder="miles"
#                     name="search_distance"
#                     value=""
#                 />
#                 <input type="text" class="flatinput searchInput postal" placeholder="from zip"
#                     size="7" name="postal" value="">
#             </div>
#
#
#     <div class="searchgroup minmax price">
# <span class="searchfieldlabel">price</span>
#     <input type="tel" name="min_price" class="flatinput min" placeholder="min" title="whole number, no letters or symbols" value="">
#     <input type="tel" name="max_price" class="flatinput max" placeholder="max" title="whole number, no letters or symbols" value="">
# </div>
#
#
#
#         <div class="searchgroup">  <span class="searchfieldlabel">make and model</span>
#   <input type="text" class="flatinput auto_make_model" placeholder="make / model" name="auto_make_model" data-autocomplete="makemodel" value=""></div><div class="searchgroup">    <div class="minmax auto_year">
# <span class="searchfieldlabel">model year</span>
#     <input type="tel" name="min_auto_year" class="flatinput min" placeholder="min" title="whole number, no letters or symbols" value="">
#     <input type="tel" name="max_auto_year" class="flatinput max" placeholder="max" title="whole number, no letters or symbols" value="">
# </div>
#     <div class="minmax auto_miles">
# <span class="searchfieldlabel">odometer</span>
#     <input type="tel" name="min_auto_miles" class="flatinput min" placeholder="min" title="whole number, no letters or symbols" value="">
#     <input type="tel" name="max_auto_miles" class="flatinput max" placeholder="max" title="whole number, no letters or symbols" value="">
# </div>
# </div><div class="searchgroup">    <div id="headerattr_condition" data-checked-count="0" data-attr="condition"
#       class="catfilter attr_picker multilink">
#
#       <span id="plusminus_condition" class="plusminus">+</span>condition
#
# </div>
#
#     <ul id="ul_condition" class="attr_list hideme">
#
#             <li class="attr_condition">
#             <label data-attr="condition">
#                 <input id="new_10" name="condition" class="multi_checkbox multi_condition" data-attr="condition"
#                   value="10" type="checkbox">
#             new
#             </label>
#         </li>
#             <li class="attr_condition">
#             <label data-attr="condition">
#                 <input id="like_new_20" name="condition" class="multi_checkbox multi_condition" data-attr="condition"
#                   value="20" type="checkbox">
#             like new
#             </label>
#         </li>
#             <li class="attr_condition">
#             <label data-attr="condition">
#                 <input id="excellent_30" name="condition" class="multi_checkbox multi_condition" data-attr="condition"
#                   value="30" type="checkbox">
#             excellent
#             </label>
#         </li>
#             <li class="attr_condition">
#             <label data-attr="condition">
#                 <input id="good_40" name="condition" class="multi_checkbox multi_condition" data-attr="condition"
#                   value="40" type="checkbox">
#             good
#             </label>
#         </li>
#             <li class="attr_condition">
#             <label data-attr="condition">
#                 <input id="fair_50" name="condition" class="multi_checkbox multi_condition" data-attr="condition"
#                   value="50" type="checkbox">
#             fair
#             </label>
#         </li>
#             <li class="attr_condition">
#             <label data-attr="condition">
#                 <input id="salvage_60" name="condition" class="multi_checkbox multi_condition" data-attr="condition"
#                   value="60" type="checkbox">
#             salvage
#             </label>
#         </li>
#
#
#
# </ul>
#
#     <div id="headerattr_auto_cylinders" data-checked-count="0" data-attr="auto_cylinders"
#       class="catfilter attr_picker multilink">
#
#       <span id="plusminus_auto_cylinders" class="plusminus">+</span>cylinders
#
# </div>
#
#     <ul id="ul_auto_cylinders" class="attr_list hideme">
#
#             <li class="attr_auto_cylinders">
#             <label data-attr="auto_cylinders">
#                 <input id="3_cylinders_1" name="auto_cylinders" class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#                   value="1" type="checkbox">
#             3 cylinders
#             </label>
#         </li>
#             <li class="attr_auto_cylinders">
#             <label data-attr="auto_cylinders">
#                 <input id="4_cylinders_2" name="auto_cylinders" class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#                   value="2" type="checkbox">
#             4 cylinders
#             </label>
#         </li>
#             <li class="attr_auto_cylinders">
#             <label data-attr="auto_cylinders">
#                 <input id="5_cylinders_3" name="auto_cylinders" class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#                   value="3" type="checkbox">
#             5 cylinders
#             </label>
#         </li>
#             <li class="attr_auto_cylinders">
#             <label data-attr="auto_cylinders">
#                 <input id="6_cylinders_4" name="auto_cylinders" class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#                   value="4" type="checkbox">
#             6 cylinders
#             </label>
#         </li>
#             <li class="attr_auto_cylinders">
#             <label data-attr="auto_cylinders">
#                 <input id="8_cylinders_5" name="auto_cylinders" class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#                   value="5" type="checkbox">
#             8 cylinders
#             </label>
#         </li>
#             <li class="attr_auto_cylinders">
#             <label data-attr="auto_cylinders">
#                 <input id="10_cylinders_6" name="auto_cylinders" class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#                   value="6" type="checkbox">
#             10 cylinders
#             </label>
#         </li>
#             <li class="attr_auto_cylinders">
#             <label data-attr="auto_cylinders">
#                 <input id="12_cylinders_7" name="auto_cylinders" class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#                   value="7" type="checkbox">
#             12 cylinders
#             </label>
#         </li>
#             <li class="attr_auto_cylinders">
#             <label data-attr="auto_cylinders">
#                 <input id="other_8" name="auto_cylinders" class="multi_checkbox multi_auto_cylinders" data-attr="auto_cylinders"
#                   value="8" type="checkbox">
#             other
#             </label>
#         </li>
#
#             <li class="selectall js-only attr_auto_cylinders">
#             <label>
#                     <input type="checkbox" data-attr="auto_cylinders" class="selectallcb multi_checkbox" checked="checked">
# ...
#             </span>
#         </span>
#     </span>
# </p>
#
#
#
#
# <p class="row" data-pid="5789025430">
#
#         <a href="/rvd/5789025430.html" class="i gallery" data-ids="1:00j0j_dWwE2CPdPI5,1:01313_ckMdCkzJCf1,1:00707_8GJmh2MiXS6,1:00z0z_5Z1aLqTndeH,1:00r0r_4jYyzp2d3CD,1:00I0I_55C6i3JQEDm,1:00303_lxBCYU94ZFE,1:00n0n_kqurAu5RWQr,1:00a0a_2wWef1O55V3,1:00F0F_j2zL8htXOna,1:00s0s_bPBiebkcRbP,1:00E0E_ccpU8lLsxt5,1:00O0O_6UeE2qe1enY,1:00N0N_jbhAiWYwW08,1:00S0S_iuq1kvsImpE">        <span class="price">$84995</span>
# </a>
#     <span class="txt">
#         <span class="pl">
#             <span class="icon icon-star" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#                 <time datetime="2016-10-17 10:32" title="Mon 17 Oct 10:32:00 AM">Oct 17</time>
#
#
#             <a href="/rvd/5789025430.html" data-id="5789025430" class="hdrlnk">2007 National RV Pacifica   1466d3ac</a>
#         </span>
#         <span class="l2">
#                     <span class="price">$84995</span>
#
#
#             <span class="pnr">
#                     <small> (Vegas)</small>
#                 <span class="px">
#                         <span class="p"> pic
#                             <span class="maptag" data-pid="5789025430">map</span>
#                         </span>
#                  </span>
#             </span>
#         </span>
#         <span class="js-only banish-unbanish">
#             <span class="banish" title="hide">
#                 <span class="icon icon-trash" role="button"></span>
#                 <span class="screen-reader-text">hide this posting</span>
#             </span>
#             <span class="unbanish" title="restore">
#                 <span class="icon icon-trash red" role="button"></span>
#                 <span class="screen-reader-text">restore this posting</span>
#             </span>
#         </span>
#     </span>
# </p>
#
#
#
#
# <p class="row" data-pid="5789100241">
#
#         <a href="/rvd/5789100241.html" class="i gallery" data-ids="1:00d0d_dHNqyeHmunB,1:00j0j_iB8QcdGr0a5,1:00y0y_cD3yFOSbjmm,1:00M0M_jzoWb03StCP,1:00v0v_clDQUlWzRr0,1:00m0m_8weTFVeIdc8,1:00P0P_aFwdpm80hC6,1:00E0E_4bZ2qT7dW7L,1:00707_bTcg4eoIHXI,1:00n0n_aNaqx2JTXr3,1:00V0V_lGnF93hoKq9,1:00101_k2l1TjxGKou,1:00505_k1LVVa1SXCf,1:00a0a_4q29szuOiW,1:00808_kj9LsiGB1xb">        <span class="price">$89995</span>
# </a>
#     <span class="txt">
#         <span class="pl">
#             <span class="icon icon-star" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#                 <time datetime="2016-10-17 10:31" title="Mon 17 Oct 10:31:49 AM">Oct 17</time>
#
#
#             <a href="/rvd/5789100241.html" data-id="5789100241" class="hdrlnk">2008 National RV Tropical   5eeabe55</a>
#         </span>
#         <span class="l2">
#                     <span class="price">$89995</span>
#
#
#             <span class="pnr">
#                     <small> (Vegas)</small>
#                 <span class="px">
#                         <span class="p"> pic
#                             <span class="maptag" data-pid="5789100241">map</span>
#                         </span>
#                  </span>
#             </span>
#         </span>
#         <span class="js-only banish-unbanish">
#             <span class="banish" title="hide">
#                 <span class="icon icon-trash" role="button"></span>
#                 <span class="screen-reader-text">hide this posting</span>
#             </span>
#             <span class="unbanish" title="restore">
#                 <span class="icon icon-trash red" role="button"></span>
#                 <span class="screen-reader-text">restore this posting</span>
#             </span>
#         </span>
#     </span>
# </p>
#
#
#
#
# <p class="row" data-pid="5822029943" data-repost-of="4878826604">
#
#         <a href="/rvs/5822029943.html" class="i gallery" data-ids="1:00N0N_bRsyMqu1PAg"></a>
#     <span class="txt">
#         <span class="pl">
#             <span class="icon icon-star" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#                 <time datetime="2016-10-17 09:10" title="Mon 17 Oct 09:10:51 AM">Oct 17</time>
#
#
#             <a href="/rvs/5822029943.html" data-id="5822029943" class="hdrlnk">PREMIER RV TAKE OVER PAYMENTS</a>
#         </span>
#         <span class="l2">
#
#
#             <span class="pnr">
#                     <small> (LAS VEGAS)</small>
#                 <span class="px">
#                         <span class="p"> pic
#                             <span class="maptag" data-pid="5822029943">map</span>
#                         </span>
#                  </span>
#             </span>
#         </span>
#         <span class="js-only banish-unbanish">
#             <span class="banish" title="hide">
#                 <span class="icon icon-trash" role="button"></span>
#                 <span class="screen-reader-text">hide this posting</span>
#             </span>
#             <span class="unbanish" title="restore">
#                 <span class="icon icon-trash red" role="button"></span>
#                 <span class="screen-reader-text">restore this posting</span>
#             </span>
#         </span>
#     </span>
# </p>
#
#
#
#
# <p class="row" data-pid="5832652690">
#
#         <a href="/rvs/5832652690.html" class="i gallery empty"></a>
#     <span class="txt">
#         <span class="pl">
#             <span class="icon icon-star" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#                 <time datetime="2016-10-17 09:08" title="Mon 17 Oct 09:08:17 AM">Oct 17</time>
#
#
#             <a href="/rvs/5832652690.html" data-id="5832652690" class="hdrlnk">RV/MOTORHOME WASH/DETAILING- INT-EXT. @ MOST REASONABLE PRICE IN TOWN</a>
#         </span>
#         <span class="l2">
#
#
#             <span class="pnr">
#                     <small> (All around D city)</small>
#                 <span class="px">
#                  </span>
#             </span>
#         </span>
#         <span class="js-only banish-unbanish">
#             <span class="banish" title="hide">
#                 <span class="icon icon-trash" role="button"></span>
#                 <span class="screen-reader-text">hide this posting</span>
#             </span>
#             <span class="unbanish" title="restore">
#                 <span class="icon icon-trash red" role="button"></span>
#                 <span class="screen-reader-text">restore this posting</span>
#             </span>
#         </span>
#     </span>
# </p>
#
#
#
#
# <p class="row" data-pid="5832625624">
#
#         <a href="/rvs/5832625624.html" class="i gallery empty"></a>
#     <span class="txt">
#         <span class="pl">
#             <span class="icon icon-star" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#                 <time datetime="2016-10-17 08:36" title="Mon 17 Oct 08:36:03 AM">Oct 17</time>
#
#
#             <a href="/rvs/5832625624.html" data-id="5832625624" class="hdrlnk">RV OXIDIZING? DULL LOOK? SHINE BRIGHT BACK 4 U @ MOST REASONABLE PRICE</a>
#         </span>
#         <span class="l2">
#
#
#             <span class="pnr">
#                     <small> (All around D valley)</small>
#                 <span class="px">
#                  </span>
#             </span>
#         </span>
#         <span class="js-only banish-unbanish">
#             <span class="banish" title="hide">
#                 <span class="icon icon-trash" role="button"></span>
#                 <span class="screen-reader-text">hide this posting</span>
#             </span>
#             <span class="unbanish" title="restore">
#                 <span class="icon icon-trash red" role="button"></span>
#                 <span class="screen-reader-text">restore this posting</span>
#             </span>
#         </span>
#     </span>
# </p>
#
#
#
#                 </div>
#                 <div id="mapcontainer" data-arealat="36.174999" data-arealon="-115.136002">
#     <div id="noresult-overlay"></div>
#     <div id="noresult-text">
#         <span class="message">No mappable items found</span>
#     </div>
#     <div id="map" class="loading"><div class="closeFS">close fullscreen</div></div>
# </div>
#
#             </div>
#
#             <div class="search-legend bottom">
#                 <div class="search-view">
#                     <span class="buttongroup"><a class="backtotop button" href="#pagecontainer">^ back to top</a></span>
#                 </div>
#                 <div class="search-sort">
#                     <span class="buttongroup"><a class="backtotop button" href="#pagecontainer">^ back to top</a></span>
#                 </div>
#                 <div class="paginator buttongroup  firstpage"><span class="resulttotal"><span class="for-map">displaying <span class="displaycountShow">...</span> postings</span></span><span class="buttons"><a href="/search/sss?query=rv" class="button first" title="first page">&lt;&lt;</a><span class="button first" title="first page">&lt;&lt;</span><a href="/search/sss?query=rv" class="button prev" title="previous page">&lt; prev</a><span class="button prev" title="previous page">&lt; prev</span><span class="button pagenum"><span class="range"><span class="rangeFrom">1</span> to <span class="rangeTo">100</span></span> of <span class="totalcount">2500</span></span><a href="/search/sss?s=100&amp;query=rv" class="button next" title="next page"> next &gt; </a><span class="button next" title="next page"> next &gt; </span></span></div>
#             </div>
#
#             <section class="blurbs">
#
#             </section>
#
#             <div id="floater">
#                 <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 <img class="payload" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#             </div>
#             <template id="gallerycarousel">
#                 <div class="slider-info"></div><div class="slider-back arrow">&lt;</div><div class="slider-forward arrow">&gt;</div>
#             </template>
#         </form>
#
#         <aside class="tsb">
#     <ul>
#         <li><a href="//www.craigslist.org/about/safety">safety tips</a>
#         <li><a href="//www.craigslist.org/about/prohibited">prohibited items</a>
#         <li><a href="//www.craigslist.org/about/recalled_items">product recalls</a>
#         <li><a href="//www.craigslist.org/about/scams">avoiding scams</a>
#     </ul>
# </aside>
#
#
#
#         <div class="slidemessage">
#     <span class="fave">
#         <span class="star"></span>
#         favorited
#     </span>
#     <span class="unfave">
#         <span class="star"></span>
#         no longer favorited
#     </span>
#     <span class="hide">
#         <span class="trash"></span>
#         hidden
#     </span>
#     <span class="unhide">
#         <span class="trash"></span>
#         no longer hidden
#     </span>
# </div>
#
#         <footer>
#         <span class="rss">
#             <a class="l" href="https://lasvegas.craigslist.org/search/sss?format=rss&amp;query=rv">RSS</a>
#             <a href="//www.craigslist.org/about/rss">(?)</a><br>
#         </span>
#     <ul class="clfooter">
#         <li>&copy;  <span class="desktop">craigslist</span><span class="mobile">CL</span></li>
#         <li><a href="//www.craigslist.org/about/help/">help</a></li>
#         <li><a href="//www.craigslist.org/about/scams">safety</a></li>
#         <li class="desktop"><a href="//www.craigslist.org/about/privacy.policy">privacy</a></li>
#         <li class="desktop"><a href="https://forums.craigslist.org/?forumID=8">feedback</a></li>
#         <li class="desktop"><a href="//www.craigslist.org/about/craigslist_is_hiring">cl jobs</a></li>
#         <li><a href="//www.craigslist.org/about/terms.of.use.en">terms</a></li>
#         <li><a href="//www.craigslist.org/about/">about</a></li>
#         <li class="fsel desktop linklike" data-mode="mobile">mobile</li>
#         <li class="fsel mobile linklike" data-mode="regular">desktop</li>
#     </ul>
# </footer>
#
#     </section>
#
#     <script src="//www.craigslist.org/js/general-concat.min.js?v=5ebb6f264ef818c30044ad679ed9876c" type="text/javascript" ></script>
#
#     <script type="text/javascript"><!--
#         var iframe = document.createElement('iframe');
#         iframe.style.display = 'none';
#         iframe.src = '//www.' + CL.url.baseDomain + '/static/localstorage.html?v=51a29e41f8e978141e4085ed4a77d170';
#         document.body.insertBefore(iframe, null);
#     --></script>
#     <script type="text/template" id="clustertemplate">
#     <li class="posting {visited}" data-pid="{PostingID}">
#         <img src="{ImageThumb}">
#         <div class="housing_bubble_banner">
#             <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#             <span class="bedrooms">{BedroomsContent}</span>
#             <span class="postingtitle"><a>{PostingTitle}</a></span>
#             <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                 <span class="banish">
#                     <span class="icon icon-trash" role="button"></span>
#                     <span class="screen-reader-text">hide this posting</span>
#                 </span>
#                 <span class="unbanish">
#                     <span class="icon icon-trash red" role="button"></span>
#                     unhide
#                 </span>
#             </span>
#         </div>
#     </li>
# </script>
# <script type="text/template" id="postingtemplate">
#     <div class="viewcontainer pics loading">
#         <div class="backtolist">
#             &laquo; back to posting list
#         </div>
#         <div class="title">
#             <span class="icon icon-star" data-pid="{PostingID}" role="button">
#                 <span class="screen-reader-text">favorite this post</span>
#             </span>
#             <span class="postingtitle">
#                 <a href="{PostingURL}" target="_blank">{PostingTitle}</a>
#             </span>
#             <div>
#                 <span class="{hasPrice}price">{currencySymbol}{Ask}</span>
#                 <span class="bedrooms">{BedroomsContent}</span>
#                 <span class="js-only map-banish-unbanish" data-pid="{PostingID}">
#                     <span class="banish">
#                         <span class="icon icon-trash" role="button"></span>
#                         <span class="screen-reader-text">hide this posting</span>
#                     </span>
#                     <span class="unbanish">
#                         <span class="icon icon-trash red" role="button"></span>
#                         <span class="screen-reader-text">unhide</span>
#                         unhide
#                     </span>
#                 </span>
#             </div>
#         </div>
#         <hr style="clear:both">
#         <div class="picscontainer gallery">
#             <span class="slider-back arrow">&lt;</span><span class="slider-info"></span><span class="slider-forward arrow">&gt;</span>
#             <div class="swipe">
#                 <div class="swipe-wrap">
#                     <img class="loading" src="//www.craigslist.org/images/animated-spinny.gif" alt="">
#                 </div>
#             </div>
#         </div>
#         <div class="infocontainer"></div>
#         <hr style="clear:both">
#         <time class="date timeago"  datetime="{isoPostedDate}">{humanPostedDate}</time>
#         <a class="viewpostinglink" href="{PostingURL}" target="_blank">view posting</a>
#         <div class="contenttoggle">
#             <a class="moreinfo">more info</a>
#             <a class="showpics">show images</a>
#         </div>
#     </div>
# </script>
# <script type="text/template" id="popuptemplate">
#     <div id="mapbubble" class="posting">
#         <ul id="clusterbubble"></ul>
#         <div id="postbubble"></div>
#     </div>
# </script>
# <script src="//www.craigslist.org/js/leaflet-concat.min.js?v=282623c9000f411a053155d1df966ad1" type="text/javascript" ></script>
#
#     <script src="//www.craigslist.org/js/search-concat.min.js?v=82fd42a19405470efcaaba46e16d6e2c" type="text/javascript" ></script>
#
# </body>
# </html>

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1.  Scrape for the largest US cities (non-exhaustive list)
# Search, research, and scrape Wikipedia for a list of the largest US cities.  There are a few sources but find one that is in a nice table.  We don't want all cities, just signifficant cities.  Examine your source.  Look for what can be differentiable.
#
# - Use requests
# - Build XPath query(ies)
# - Extract to a list
# - Clean your list

# %%
largest_cities = requests.get("https://en.wikipedia.org/wiki/List_of_Metropolitan_Statistical_Areas")
HTML_lc = largest_cities.text  
HTML[0:150]
# Out:
# u'\ufeff<!DOCTYPE html>\n\n<html class="no-js"><head>\n    <title>las vegas for sale &quot;rv&quot; - craigslist</title>\n\n    <meta name="description" content="'

# %%
print HTML_lc
Selector(text=HTML).xpath('//li[@id="kiefer-views-per-hour"]/text()').extract()
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of Metropolitan Statistical Areas - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"List_of_Metropolitan_Statistical_Areas","wgTitle":"List of Metropolitan Statistical Areas","wgCurRevisionId":745054878,"wgRevisionId":745054878,"wgArticleId":9809857,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Metropolitan statistical areas of the United States","Core based statistical areas of the United States","Lists of metropolitan areas","United States demography-related lists"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"List_of_Metropolitan_Statistical_Areas","wgRelevantArticleId":9809857,"wgRequestId":"WAbpFApAMEcAADZ-EJoAAAAP","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":false},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgFlaggedRevsParams":{"tags":{"status":{"levels":1,"quality":2,"pristine":3}}},"wgStableRevisionId":null,"wgWikibaseItemId":"Q4387868","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user.cssprefs":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["mediawiki.page.startup","mediawiki.legacy.wikibits","ext.centralauth.centralautologin","mmv.head","ext.visualEditor.desktopArticleTarget.init","ext.uls.interface","ext.quicksurveys.init","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.gadget.ReferenceTooltips%2Cfeatured-articles-links%2Cteahouse%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.28.0-wmf.22"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/List_of_Metropolitan_Statistical_Areas"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/List_of_Metropolitan_Statistical_Areas"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-List_of_Metropolitan_Statistical_Areas rootpage-List_of_Metropolitan_Statistical_Areas skin-vector action-view feature-footer-v2">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">List of Metropolitan Statistical Areas</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><div role="note" class="hatnote">For a list of all US metropolitan areas regardless of size see <a href="/wiki/List_of_primary_statistical_areas_of_the_United_States" title="List of primary statistical areas of the United States">List of primary statistical areas of the United States</a>, this article only includes those statistical areas which have an urban core area of over 50,000</div>
# <div role="note" class="hatnote">Main article: <a href="/wiki/Metropolitan_statistical_area" title="Metropolitan statistical area">Metropolitan statistical area</a></div>
# <table class="vertical-navbox nowraplinks navbox" style="float:right;clear:right;width:22.0em;margin:0 0 1.0em 1.0em;background:#f9f9f9;border:1px solid #aaa;padding:0.2em;border-spacing:0.4em 0;text-align:center;line-height:1.4em;font-size:88%">
# <tr>
# <th style="padding:0.2em 0.4em 0.2em;font-size:145%;line-height:1.2em">Population tables<br />
# of U.S. cities</th>
# </tr>
# <tr>
# <td style="padding:0.2em 0 0.4em"><a href="/wiki/File:Pano_Manhattan2007_amk.jpg" class="image"><img alt="&quot;New York City skyline&quot;" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Pano_Manhattan2007_amk.jpg/250px-Pano_Manhattan2007_amk.jpg" width="250" height="72" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Pano_Manhattan2007_amk.jpg/375px-Pano_Manhattan2007_amk.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Pano_Manhattan2007_amk.jpg/500px-Pano_Manhattan2007_amk.jpg 2x" data-file-width="2764" data-file-height="800" /></a></td>
# </tr>
# <tr>
# <th style="padding:0.1em"><a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">Cities</a></th>
# </tr>
# <tr>
# <td style="padding:0 0.1em 0.4em">
# <p><span style="font-size:110%;"><a href="/wiki/List_of_United_States_cities_by_population" title="List of United States cities by population">Population</a></span></p>
# <div class="hlist">
# <ul>
# <li><a href="/wiki/List_of_United_States_cities_by_area" title="List of United States cities by area">Area</a></li>
# <li><a href="/wiki/List_of_United_States_cities_by_population_density" title="List of United States cities by population density">Density</a></li>
# <li><a href="/wiki/Lists_of_United_States_cities_with_large_ethnic_identity_populations" class="mw-redirect" title="Lists of United States cities with large ethnic identity populations">Ethnic identity</a></li>
# <li><a href="/wiki/List_of_United_States_cities_by_foreign-born_population" title="List of United States cities by foreign-born population">Foreign-born</a></li>
# <li><a href="/wiki/Highest-income_metropolitan_statistical_areas_in_the_United_States" title="Highest-income metropolitan statistical areas in the United States">Income</a></li>
# <li><a href="/wiki/List_of_United_States_cities_by_Spanish-speaking_population" title="List of United States cities by Spanish-speaking population">Spanish speakers</a></li>
# <li><a href="/wiki/Largest_cities_in_the_United_States_by_population_by_decade" title="Largest cities in the United States by population by decade">By decade</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr>
# <th style="padding:0.1em"><a href="/wiki/List_of_United_States_urban_areas" title="List of United States urban areas">Urban areas</a></th>
# </tr>
# <tr>
# <td style="padding:0 0.1em 0.4em"><a href="/wiki/Cities_and_metropolitan_areas_of_the_United_States" title="Cities and metropolitan areas of the United States">Populous cities and metropolitan areas</a></td>
# </tr>
# <tr>
# <th style="padding:0.1em"><a href="/wiki/List_of_metropolitan_areas_of_the_United_States" title="List of metropolitan areas of the United States">Metropolitan areas</a></th>
# </tr>
# <tr>
# <td style="padding:0 0.1em 0.4em">
# <div class="plainlist">
# <ul>
# <li><a href="/wiki/List_of_primary_statistical_areas_of_the_United_States" title="List of primary statistical areas of the United States">574 Primary Statistical Areas</a></li>
# <li><a href="/wiki/List_of_Combined_Statistical_Areas" class="mw-redirect" title="List of Combined Statistical Areas">169 Combined Statistical Areas</a></li>
# <li><a href="/wiki/List_of_Core_Based_Statistical_Areas" title="List of Core Based Statistical Areas">929 Core Based Statistical Areas</a></li>
# <li><strong class="selflink">389 Metropolitan Statistical Areas</strong></li>
# <li><a href="/wiki/List_of_Micropolitan_Statistical_Areas" class="mw-redirect" title="List of Micropolitan Statistical Areas">540 Micropolitan Statistical Areas</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr>
# <th style="padding:0.1em"><a href="/wiki/Megaregions_of_the_United_States" title="Megaregions of the United States">Megaregions</a></th>
# </tr>
# <tr>
# <td class="navbox-abovebelow" style="padding:0.3em 0.4em 0.3em;font-weight:bold;line-height:1.3em;font-weight:normal;">
# <div class="plainlist">
# <ul>
# <li><b>See also</b></li>
# <li><a href="/wiki/List_of_North_American_metropolitan_areas_by_population" title="List of North American metropolitan areas by population">North American metro areas</a></li>
# <li><a href="/wiki/List_of_cities_proper_by_population" title="List of cities proper by population">World cities</a></li>
# </ul>
# </div>
# </td>
# </tr>
# <tr>
# <td style="text-align:right;font-size:115%">
# <div class="plainlinks hlist navbar mini">
# <ul>
# <li class="nv-view"><a href="/wiki/Template:U.S._city_population_tables" title="Template:U.S. city population tables"><abbr title="View this template">v</abbr></a></li>
# <li class="nv-talk"><a href="/wiki/Template_talk:U.S._city_population_tables" title="Template talk:U.S. city population tables"><abbr title="Discuss this template">t</abbr></a></li>
# <li class="nv-edit"><a class="external text" href="//en.wikipedia.org/w/index.php?title=Template:U.S._city_population_tables&amp;action=edit"><abbr title="Edit this template">e</abbr></a></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# <p>The <a href="/wiki/Office_of_Management_and_Budget" title="Office of Management and Budget">United States Office of Management and Budget</a> (OMB) has defined 382 <a href="/wiki/Metropolitan_Statistical_Area" class="mw-redirect" title="Metropolitan Statistical Area">Metropolitan Statistical Areas</a> (MSAs) for the <a href="/wiki/United_States" title="United States">United States</a> and seven for <a href="/wiki/Puerto_Rico" title="Puerto Rico">Puerto Rico</a>.<sup id="cite_ref-OMB_13-01_1-0" class="reference"><a href="#cite_note-OMB_13-01-1">[1]</a></sup> The OMB defines a Metropolitan Statistical Area as one or more adjacent <a href="/wiki/County_(United_States)" title="County (United States)">counties</a> or <a href="/wiki/County-equivalent" class="mw-redirect" title="County-equivalent">county equivalents</a> that have at least one <a href="/wiki/List_of_United_States_urban_areas" title="List of United States urban areas">urban core area</a> of at least 50,000 population, plus adjacent territory that has a high degree of social and economic integration with the core as measured by commuting ties.</p>
# <p></p>
# <div id="toc" class="toc">
# <div id="toctitle">
# <h2>Contents</h2>
# </div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#United_States"><span class="tocnumber">1</span> <span class="toctext">United States</span></a></li>
# <li class="toclevel-1 tocsection-2"><a href="#Puerto_Rico"><span class="tocnumber">2</span> <span class="toctext">Puerto Rico</span></a></li>
# <li class="toclevel-1 tocsection-3"><a href="#See_also"><span class="tocnumber">3</span> <span class="toctext">See also</span></a></li>
# <li class="toclevel-1 tocsection-4"><a href="#References"><span class="tocnumber">4</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-5"><a href="#External_links"><span class="tocnumber">5</span> <span class="toctext">External links</span></a></li>
# </ul>
# </div>
# <p></p>
# <h2><span class="mw-headline" id="United_States">United States</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;action=edit&amp;section=1" title="Edit section: United States">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="thumb tright">
# <div class="thumbinner" style="width:302px;"><a href="/wiki/File:Metropolitan_and_Micropolitan_Statistical_Areas_(CBSAs)_of_the_United_States_and_Puerto_Rico,_Feb_2013.gif" class="image"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/16/Metropolitan_and_Micropolitan_Statistical_Areas_%28CBSAs%29_of_the_United_States_and_Puerto_Rico%2C_Feb_2013.gif/300px-Metropolitan_and_Micropolitan_Statistical_Areas_%28CBSAs%29_of_the_United_States_and_Puerto_Rico%2C_Feb_2013.gif" width="300" height="191" class="thumbimage" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/16/Metropolitan_and_Micropolitan_Statistical_Areas_%28CBSAs%29_of_the_United_States_and_Puerto_Rico%2C_Feb_2013.gif/450px-Metropolitan_and_Micropolitan_Statistical_Areas_%28CBSAs%29_of_the_United_States_and_Puerto_Rico%2C_Feb_2013.gif 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/16/Metropolitan_and_Micropolitan_Statistical_Areas_%28CBSAs%29_of_the_United_States_and_Puerto_Rico%2C_Feb_2013.gif/600px-Metropolitan_and_Micropolitan_Statistical_Areas_%28CBSAs%29_of_the_United_States_and_Puerto_Rico%2C_Feb_2013.gif 2x" data-file-width="3850" data-file-height="2446" /></a>
# <div class="thumbcaption">
# <div class="magnify"><a href="/wiki/File:Metropolitan_and_Micropolitan_Statistical_Areas_(CBSAs)_of_the_United_States_and_Puerto_Rico,_Feb_2013.gif" class="internal" title="Enlarge"></a></div>
# An enlargeable map of the 929 <a href="/wiki/Core_Based_Statistical_Area" class="mw-redirect" title="Core Based Statistical Area">Core Based Statistical Areas</a> (CBSAs) of the <a href="/wiki/United_States" title="United States">United States</a> and <a href="/wiki/Puerto_Rico" title="Puerto Rico">Puerto Rico</a>. The 382 <a href="/wiki/Metropolitan_Statistical_Area" class="mw-redirect" title="Metropolitan Statistical Area">Metropolitan Statistical Areas</a> (MSAs) are shown in <span style="color:#008060;">medium green</span>. The 541 <a href="/wiki/Micropolitan_Statistical_Area" class="mw-redirect" title="Micropolitan Statistical Area">Micropolitan Statistical Areas</a> (μSAs) are shown in <span style="color:#609f8f;">light green</span>.</div>
# </div>
# </div>
# <p>The following <a href="/wiki/Help:Sorting" title="Help:Sorting">sortable</a> <a href="/wiki/Help:Table" title="Help:Table">table</a> lists the 382 Metropolitan Statistical Areas (MSAs) of the United States with the following information:</p>
# <ol>
# <li>The MSA rank by population as of July 1, 2015, as estimated by the <a href="/wiki/United_States_Census_Bureau" title="United States Census Bureau">United States Census Bureau</a><sup id="cite_ref-PopEstCBSA_2-0" class="reference"><a href="#cite_note-PopEstCBSA-2">[2]</a></sup></li>
# <li>The MSA name as designated by the <a href="/wiki/United_States_Office_of_Management_and_Budget" class="mw-redirect" title="United States Office of Management and Budget">United States Office of Management and Budget</a><sup id="cite_ref-OMB_13-01_1-1" class="reference"><a href="#cite_note-OMB_13-01-1">[1]</a></sup></li>
# <li>The MSA population as of July 1, 2015, as estimated by the United States Census Bureau<sup id="cite_ref-PopEstCBSA_2-1" class="reference"><a href="#cite_note-PopEstCBSA-2">[2]</a></sup></li>
# <li>The MSA population as of April 1, 2010, as enumerated by the <a href="/wiki/2010_United_States_Census" title="2010 United States Census">2010 United States Census</a><sup id="cite_ref-PopEstCBSA_2-2" class="reference"><a href="#cite_note-PopEstCBSA-2">[2]</a></sup></li>
# <li>The percent MSA population change from April 1, 2010, to July 1, 2015<sup id="cite_ref-PopEstCBSA_2-3" class="reference"><a href="#cite_note-PopEstCBSA-2">[2]</a></sup></li>
# <li>The <a href="/wiki/Combined_Statistical_Area" class="mw-redirect" title="Combined Statistical Area">Combined Statistical Area</a> (CSA)<sup id="cite_ref-CSA_3-0" class="reference"><a href="#cite_note-CSA-3">[3]</a></sup> if the MSA is a component<sup id="cite_ref-OMB_13-01_1-2" class="reference"><a href="#cite_note-OMB_13-01-1">[1]</a></sup></li>
# </ol>
# <div style="clear:both;"></div>
# <table class="wikitable sortable">
# <caption><big>The 382 Metropolitan Statistical Areas of the United States of America</big><br />
# <br /></caption>
# <tr>
# <th>Rank</th>
# <th>Metropolitan&#160;Statistical&#160;Area</th>
# <th>2015 Estimate</th>
# <th>2010 Census</th>
# <th>Change</th>
# <th>Encompassing Combined Statistical&#160;Area</th>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000100000000000000♠</span>1</td>
# <td><a href="/wiki/New_York_metropolitan_area#Metropolitan_Statistical_Area" title="New York metropolitan area">New York-Newark-Jersey City, NY-NJ-PA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">20,182,305</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">19,567,410</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000314244450338600♠</span><font style="color:green">+3.14%</font></td>
# <td><a href="/wiki/New_York_metropolitan_area#Combined_Statistical_Area" title="New York metropolitan area">New York-Newark, NY-NJ-CT-PA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000200000000000000♠</span>2</td>
# <td><a href="/wiki/Los_Angeles_metropolitan_area" title="Los Angeles metropolitan area">Los Angeles-Long Beach-Anaheim, CA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">13,340,068</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">12,828,837</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000398501438594940♠</span><font style="color:green">+3.99%</font></td>
# <td><a href="/wiki/Greater_Los_Angeles_Area#Combined_Statistical_Area" title="Greater Los Angeles Area">Los Angeles-Long Beach, CA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000300000000000000♠</span>3</td>
# <td><a href="/wiki/Chicago_metropolitan_area#Metropolitan_statistical_area" title="Chicago metropolitan area">Chicago-Naperville-Elgin, IL-IN-WI Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">9,551,031</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">9,461,105</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">6999950480942765150♠</span><font style="color:green">+0.95%</font></td>
# <td><a href="/wiki/Chicago_metropolitan_area#Combined_Statistical_Area" title="Chicago metropolitan area">Chicago-Naperville, IL-IN-WI Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000400000000000000♠</span>4</td>
# <td><a href="/wiki/Dallas-Fort_Worth_metroplex#Combined_Statistical_Area" class="mw-redirect" title="Dallas-Fort Worth metroplex">Dallas-Fort Worth-Arlington, TX Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">7,102,796</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">6,426,214</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7001105284697957460♠</span><font style="color:green">+10.53%</font></td>
# <td><a href="/wiki/Dallas-Fort_Worth_metroplex#Combined_Statistical_Area" class="mw-redirect" title="Dallas-Fort Worth metroplex">Dallas-Fort Worth, TX-OK Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000500000000000000♠</span>5</td>
# <td><a href="/wiki/Greater_Houston" title="Greater Houston">Houston-The Woodlands-Sugar Land, TX Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">6,656,947</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">5,920,416</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7001124405278277740♠</span><font style="color:green">+12.44%</font></td>
# <td><a href="/wiki/Greater_Houston" title="Greater Houston">Houston-The Woodlands, TX Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000600000000000000♠</span>6</td>
# <td><a href="/wiki/Washington_metropolitan_area" title="Washington metropolitan area">Washington-Arlington-Alexandria, DC-VA-MD-WV Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">6,097,684</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">5,636,232</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000818724282463890♠</span><font style="color:green">+8.19%</font></td>
# <td><a href="/wiki/Washington_metropolitan_area" title="Washington metropolitan area">Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000700000000000000♠</span>7</td>
# <td><a href="/wiki/Delaware_Valley" title="Delaware Valley">Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">6,069,875</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">5,965,343</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000175232170220560♠</span><font style="color:green">+1.75%</font></td>
# <td><a href="/wiki/Delaware_Valley" title="Delaware Valley">Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000800000000000000♠</span>8</td>
# <td><a href="/wiki/Miami_metropolitan_area" title="Miami metropolitan area">Miami-Fort Lauderdale-West Palm Beach, FL Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">6,012,331</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">5,564,635</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000804537943638710♠</span><font style="color:green">+8.05%</font></td>
# <td><a href="/wiki/Miami_metropolitan_area" title="Miami metropolitan area">Miami-Fort Lauderdale-Port St. Lucie, FL Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7000900000000000000♠</span>9</td>
# <td><a href="/wiki/Atlanta_metropolitan_area" title="Atlanta metropolitan area">Atlanta-Sandy Springs-Roswell, GA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">5,710,795</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">5,286,728</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000802135082417710♠</span><font style="color:green">+8.02%</font></td>
# <td><a href="/wiki/Atlanta_metropolitan_area" title="Atlanta metropolitan area">Atlanta-Sandy Springs, GA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001100000000000000♠</span>10</td>
# <td><a href="/wiki/Greater_Boston#Metropolitan_Statistical_Area" title="Greater Boston">Boston-Cambridge-Newton, MA-NH Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,774,321</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,552,402</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000487476721080429♠</span><font style="color:green">+4.87%</font></td>
# <td><a href="/wiki/Greater_Boston#Combined_statistical_area" title="Greater Boston">Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001110000000000000♠</span>11</td>
# <td><a href="/wiki/San_Francisco%E2%80%93Oakland%E2%80%93Hayward,_CA_Metropolitan_Statistical_Area" title="San Francisco–Oakland–Hayward, CA Metropolitan Statistical Area">San Francisco–Oakland–Hayward, CA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,656,132</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,335,391</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000739820237667140♠</span><font style="color:green">+7.40%</font></td>
# <td><a href="/wiki/San_Jose-San_Francisco-Oakland,_CA_Combined_Statistical_Area" title="San Jose-San Francisco-Oakland, CA Combined Statistical Area">San Jose-San Francisco-Oakland, CA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001120000000000000♠</span>12</td>
# <td><a href="/wiki/Phoenix-Mesa-Scottsdale,_AZ_Metropolitan_Statistical_Area" class="mw-redirect" title="Phoenix-Mesa-Scottsdale, AZ Metropolitan Statistical Area">Phoenix-Mesa-Scottsdale, AZ Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,574,531</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,192,887</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000910217709182240♠</span><font style="color:green">+9.10%</font></td>
# <td></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001130000000000000♠</span>13</td>
# <td><a href="/wiki/Riverside-San_Bernardino-Ontario,_CA_Metropolitan_Statistical_Area" class="mw-redirect" title="Riverside-San Bernardino-Ontario, CA Metropolitan Statistical Area">Riverside-San Bernardino-Ontario, CA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,489,159</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,224,851</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000625603127778940♠</span><font style="color:green">+6.26%</font></td>
# <td><a href="/wiki/Los_Angeles-Long_Beach,_CA_Combined_Statistical_Area" class="mw-redirect" title="Los Angeles-Long Beach, CA Combined Statistical Area">Los Angeles-Long Beach, CA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001140000000000000♠</span>14</td>
# <td><a href="/wiki/Detroit-Warren-Dearborn,_MI_Metropolitan_Statistical_Area" class="mw-redirect" title="Detroit-Warren-Dearborn, MI Metropolitan Statistical Area">Detroit-Warren-Dearborn, MI Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,302,043</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">4,296,250</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">6999134838521966830♠</span><font style="color:green">+0.13%</font></td>
# <td><a href="/wiki/Detroit-Warren-Ann_Arbor,_MI_Combined_Statistical_Area" class="mw-redirect" title="Detroit-Warren-Ann Arbor, MI Combined Statistical Area">Detroit-Warren-Ann Arbor, MI Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001150000000000000♠</span>15</td>
# <td><a href="/wiki/Seattle_metropolitan_area" title="Seattle metropolitan area">Seattle-Tacoma-Bellevue, WA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">3,733,580</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">3,439,809</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000854032883802560♠</span><font style="color:green">+8.54%</font></td>
# <td><a href="/wiki/Seattle-Tacoma,_WA_Combined_Statistical_Area" class="mw-redirect" title="Seattle-Tacoma, WA Combined Statistical Area">Seattle-Tacoma, WA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001160000000000000♠</span>16</td>
# <td><a href="/wiki/Minneapolis-St._Paul-Bloomington,_MN-WI_Metropolitan_Statistical_Area" class="mw-redirect" title="Minneapolis-St. Paul-Bloomington, MN-WI Metropolitan Statistical Area">Minneapolis-St. Paul-Bloomington, MN-WI Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">3,524,583</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">3,348,859</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000524727974513110♠</span><font style="color:green">+5.25%</font></td>
# <td><a href="/wiki/Minneapolis-St._Paul,_MN-WI_Combined_Statistical_Area" class="mw-redirect" title="Minneapolis-St. Paul, MN-WI Combined Statistical Area">Minneapolis-St. Paul, MN-WI Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001170000000000000♠</span>17</td>
# <td><a href="/wiki/San_Diego-Carlsbad,_CA_Metropolitan_Statistical_Area" class="mw-redirect" title="San Diego-Carlsbad, CA Metropolitan Statistical Area">San Diego-Carlsbad, CA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">3,299,521</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">3,095,313</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000659732957539350♠</span><font style="color:green">+6.60%</font></td>
# <td></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001180000000000000♠</span>18</td>
# <td><a href="/wiki/Tampa-St._Petersburg-Clearwater,_FL_Metropolitan_Statistical_Area" class="mw-redirect" title="Tampa-St. Petersburg-Clearwater, FL Metropolitan Statistical Area">Tampa-St. Petersburg-Clearwater, FL Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,975,225</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,783,243</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000689778075432150♠</span><font style="color:green">+6.90%</font></td>
# <td></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001190000000000000♠</span>19</td>
# <td><a href="/wiki/Denver-Aurora-Lakewood,_CO_Metropolitan_Statistical_Area" class="mw-redirect" title="Denver-Aurora-Lakewood, CO Metropolitan Statistical Area">Denver-Aurora-Lakewood, CO Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,814,330</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,543,482</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7001106487091318120♠</span><font style="color:green">+10.65%</font></td>
# <td><a href="/wiki/Denver-Aurora-Lakewood,_CO_Metropolitan_Statistical_Area" class="mw-redirect" title="Denver-Aurora-Lakewood, CO Metropolitan Statistical Area">Denver-Aurora-Lakewood, CO Metropolitan Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001200000000000000♠</span>20</td>
# <td><a href="/wiki/St._Louis,_MO-IL_Metropolitan_Statistical_Area" class="mw-redirect" title="St. Louis, MO-IL Metropolitan Statistical Area">St. Louis, MO-IL Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,811,588</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,787,701</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">6999856870948498420♠</span><font style="color:green">+0.86%</font></td>
# <td><a href="/wiki/St._Louis-St._Charles-Farmington,_MO-IL_Combined_Statistical_Area" class="mw-redirect" title="St. Louis-St. Charles-Farmington, MO-IL Combined Statistical Area">St. Louis-St. Charles-Farmington, MO-IL Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001210000000000000♠</span>21</td>
# <td><a href="/wiki/Baltimore-Columbia-Towson,_MD_Metropolitan_Statistical_Area" class="mw-redirect" title="Baltimore-Columbia-Towson, MD Metropolitan Statistical Area">Baltimore-Columbia-Towson, MD Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,797,407</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,710,489</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000320672764213390♠</span><font style="color:green">+3.21%</font></td>
# <td><a href="/wiki/Washington-Baltimore-Arlington,_DC-MD-VA-WV-PA_Combined_Statistical_Area" class="mw-redirect" title="Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area">Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001220000000000000♠</span>22</td>
# <td><a href="/wiki/Charlotte-Concord-Gastonia,_NC-SC_Metropolitan_Statistical_Area" class="mw-redirect" title="Charlotte-Concord-Gastonia, NC-SC Metropolitan Statistical Area">Charlotte-Concord-Gastonia, NC-SC Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,426,363</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,217,012</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000944293490517869♠</span><font style="color:green">+9.44%</font></td>
# <td><a href="/wiki/Charlotte-Concord,_NC-SC_Combined_Statistical_Area" class="mw-redirect" title="Charlotte-Concord, NC-SC Combined Statistical Area">Charlotte-Concord, NC-SC Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001230000000000000♠</span>23</td>
# <td><a href="/wiki/Portland-Vancouver-Hillsboro,_OR-WA_Metropolitan_Statistical_Area" class="mw-redirect" title="Portland-Vancouver-Hillsboro, OR-WA Metropolitan Statistical Area">Portland-Vancouver-Hillsboro, OR-WA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,389,228</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,226,009</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000733236029144540♠</span><font style="color:green">+7.33%</font></td>
# <td><a href="/wiki/Portland-Vancouver-Salem,_OR-WA_Combined_Statistical_Area" class="mw-redirect" title="Portland-Vancouver-Salem, OR-WA Combined Statistical Area">Portland-Vancouver-Salem, OR-WA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001240000000000000♠</span>24</td>
# <td><a href="/wiki/Orlando-Kissimmee-Sanford,_FL_Metropolitan_Statistical_Area" class="mw-redirect" title="Orlando-Kissimmee-Sanford, FL Metropolitan Statistical Area">Orlando-Kissimmee-Sanford, FL Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,387,138</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,134,411</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7001118405967735360♠</span><font style="color:green">+11.84%</font></td>
# <td><a href="/wiki/Orlando-Deltona-Daytona_Beach,_FL_Combined_Statistical_Area" class="mw-redirect" title="Orlando-Deltona-Daytona Beach, FL Combined Statistical Area">Orlando-Deltona-Daytona Beach, FL Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001250000000000000♠</span>25</td>
# <td><a href="/wiki/San_Antonio-New_Braunfels,_TX_Metropolitan_Statistical_Area" class="mw-redirect" title="San Antonio-New Braunfels, TX Metropolitan Statistical Area">San Antonio-New Braunfels, TX Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,384,075</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,142,508</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7001112749637340909♠</span><font style="color:green">+11.27%</font></td>
# <td></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001260000000000000♠</span>26</td>
# <td><a href="/wiki/Pittsburgh,_PA_Metropolitan_Statistical_Area" class="mw-redirect" title="Pittsburgh, PA Metropolitan Statistical Area">Pittsburgh, PA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,353,045</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,356,285</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">3000862495411208750♠</span><font style="color:red">−0.14%</font></td>
# <td><a href="/wiki/Pittsburgh-New_Castle-Weirton,_PA-OH-WV_Combined_Statistical_Area" class="mw-redirect" title="Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area">Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001270000000000000♠</span>27</td>
# <td><a href="/wiki/Sacramento%E2%80%93Roseville%E2%80%93Arden-Arcade,_CA_Metropolitan_Statistical_Area" class="mw-redirect" title="Sacramento–Roseville–Arden-Arcade, CA Metropolitan Statistical Area">Sacramento–Roseville–Arden-Arcade, CA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,274,194</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,149,127</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000581943272780060♠</span><font style="color:green">+5.82%</font></td>
# <td><a href="/wiki/Sacramento-Roseville,_CA_Combined_Statistical_Area" class="mw-redirect" title="Sacramento-Roseville, CA Combined Statistical Area">Sacramento-Roseville, CA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001280000000000000♠</span>28</td>
# <td><a href="/wiki/Cincinnati,_OH-KY-IN_Metropolitan_Statistical_Area" class="mw-redirect" title="Cincinnati, OH-KY-IN Metropolitan Statistical Area">Cincinnati, OH-KY-IN Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,157,719</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,114,580</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000204007415184100♠</span><font style="color:green">+2.04%</font></td>
# <td><a href="/wiki/Cincinnati-Wilmington-Maysville,_OH-KY-IN_Combined_Statistical_Area" class="mw-redirect" title="Cincinnati-Wilmington-Maysville, OH-KY-IN Combined Statistical Area">Cincinnati-Wilmington-Maysville, OH-KY-IN Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001290000000000000♠</span>29</td>
# <td><a href="/wiki/Las_Vegas-Henderson-Paradise,_NV_Metropolitan_Statistical_Area" class="mw-redirect" title="Las Vegas-Henderson-Paradise, NV Metropolitan Statistical Area">Las Vegas-Henderson-Paradise, NV Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,114,801</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,951,269</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000838080244189810♠</span><font style="color:green">+8.38%</font></td>
# <td><a href="/wiki/Las_Vegas-Henderson,_NV-AZ_Combined_Statistical_Area" class="mw-redirect" title="Las Vegas-Henderson, NV-AZ Combined Statistical Area">Las Vegas-Henderson, NV-AZ Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001300000000000000♠</span>30</td>
# <td><a href="/wiki/Kansas_City,_MO-KS_Metropolitan_Statistical_Area" class="mw-redirect" title="Kansas City, MO-KS Metropolitan Statistical Area">Kansas City, MO-KS Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,087,471</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,009,342</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000388828780765050♠</span><font style="color:green">+3.89%</font></td>
# <td><a href="/wiki/Kansas_City-Overland_Park-Kansas_City,_MO-KS_Combined_Statistical_Area" class="mw-redirect" title="Kansas City-Overland Park-Kansas City, MO-KS Combined Statistical Area">Kansas City-Overland Park-Kansas City, MO-KS Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001310000000000000♠</span>31</td>
# <td><a href="/wiki/Cleveland-Elyria,_OH_Metropolitan_Statistical_Area" class="mw-redirect" title="Cleveland-Elyria, OH Metropolitan Statistical Area">Cleveland-Elyria, OH Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,060,810</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,077,240</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">3000209046619552869♠</span><font style="color:red">−0.79%</font></td>
# <td><a href="/wiki/Cleveland-Akron-Canton,_OH_Combined_Statistical_Area" class="mw-redirect" title="Cleveland-Akron-Canton, OH Combined Statistical Area">Cleveland-Akron-Canton, OH Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001320000000000000♠</span>32</td>
# <td><a href="/wiki/Columbus,_OH_Metropolitan_Statistical_Area" class="mw-redirect" title="Columbus, OH Metropolitan Statistical Area">Columbus, OH Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,021,632</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,901,974</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000629125319273560♠</span><font style="color:green">+6.29%</font></td>
# <td><a href="/wiki/Columbus-Marion-Zanesville,_OH_Combined_Statistical_Area" class="mw-redirect" title="Columbus-Marion-Zanesville, OH Combined Statistical Area">Columbus-Marion-Zanesville, OH Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001330000000000000♠</span>33</td>
# <td><a href="/wiki/Austin-Round_Rock,_TX_Metropolitan_Statistical_Area" class="mw-redirect" title="Austin-Round Rock, TX Metropolitan Statistical Area">Austin-Round Rock, TX Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">2,000,860</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,716,289</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7001165805991881319♠</span><font style="color:green">+16.58%</font></td>
# <td></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001340000000000000♠</span>34</td>
# <td><a href="/wiki/Indianapolis-Carmel-Anderson,_IN_Metropolitan_Statistical_Area" class="mw-redirect" title="Indianapolis-Carmel-Anderson, IN Metropolitan Statistical Area">Indianapolis-Carmel-Anderson, IN Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,988,817</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,887,877</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000534674663656579♠</span><font style="color:green">+5.35%</font></td>
# <td><a href="/wiki/Indianapolis-Carmel-Muncie,_IN_Combined_Statistical_Area" class="mw-redirect" title="Indianapolis-Carmel-Muncie, IN Combined Statistical Area">Indianapolis-Carmel-Muncie, IN Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001350000000000000♠</span>35</td>
# <td><a href="/wiki/San_Jose-Sunnyvale-Santa_Clara,_CA_Metropolitan_Statistical_Area" class="mw-redirect" title="San Jose-Sunnyvale-Santa Clara, CA Metropolitan Statistical Area">San Jose-Sunnyvale-Santa Clara, CA Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,976,836</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,836,911</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000761740770238730♠</span><font style="color:green">+7.62%</font></td>
# <td><a href="/wiki/San_Jose-San_Francisco-Oakland,_CA_Combined_Statistical_Area" title="San Jose-San Francisco-Oakland, CA Combined Statistical Area">San Jose-San Francisco-Oakland, CA Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001360000000000000♠</span>36</td>
# <td><a href="/wiki/Nashville-Davidson%E2%80%93Murfreesboro%E2%80%93Franklin,_TN_Metropolitan_Statistical_Area" class="mw-redirect" title="Nashville-Davidson–Murfreesboro–Franklin, TN Metropolitan Statistical Area">Nashville-Davidson–Murfreesboro–Franklin, TN Metropolitan Statistical Area</a></td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,830,345</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9">1,670,890</td>
# <td align="right" rowspan="1" bgcolor="#F9F9F9"><span style="display:none" class="sortkey">7000954311773964770♠</span><font style="color:green">+9.54%</font></td>
# <td><a href="/wiki/Nashville-Davidson%E2%80%93Murfreesboro,_TN_Combined_Statistical_Area" class="mw-redirect" title="Nashville-Davidson–Murfreesboro, TN Combined Statistical Area">Nashville-Davidson–Murfreesboro, TN Combined Statistical Area</a></td>
# </tr>
# <tr>
# <td align="center"><span style="display:none" class="sortkey">7001370000000000000♠</span>37</td>
# ...
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=List+of+Metropolitan+Statistical+Areas" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=List+of+Metropolitan+Statistical+Areas" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/List_of_Metropolitan_Statistical_Areas"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:List_of_Metropolitan_Statistical_Areas"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/List_of_Metropolitan_Statistical_Areas" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/List_of_Metropolitan_Statistical_Areas" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/List_of_Metropolitan_Statistical_Areas" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;oldid=745054878" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q4387868" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=List_of_Metropolitan_Statistical_Areas&amp;id=745054878" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=List+of+Metropolitan+Statistical+Areas">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=List+of+Metropolitan+Statistical+Areas&amp;returnto=List+of+Metropolitan+Statistical+Areas&amp;oldid=745054878&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li class="interlanguage-link interwiki-es"><a href="https://es.wikipedia.org/wiki/Anexo:%C3%81reas_metropolitanas_de_Estados_Unidos" title="Anexo:Áreas metropolitanas de Estados Unidos – Spanish" lang="es" hreflang="es" class="interlanguage-link-target">Español</a></li><li class="interlanguage-link interwiki-gl"><a href="https://gl.wikipedia.org/wiki/Lista_de_%C3%81reas_Estat%C3%ADsticas_Metropolitanas" title="Lista de Áreas Estatísticas Metropolitanas – Galician" lang="gl" hreflang="gl" class="interlanguage-link-target">Galego</a></li><li class="interlanguage-link interwiki-ja"><a href="https://ja.wikipedia.org/wiki/%E3%82%A2%E3%83%A1%E3%83%AA%E3%82%AB%E5%90%88%E8%A1%86%E5%9B%BD%E3%81%AE%E4%B8%BB%E3%81%AA%E9%83%BD%E5%B8%82%E5%9C%8F%E4%BA%BA%E5%8F%A3%E3%81%AE%E9%A0%86%E4%BD%8D" title="アメリカ合衆国の主な都市圏人口の順位 – Japanese" lang="ja" hreflang="ja" class="interlanguage-link-target">日本語</a></li><li class="interlanguage-link interwiki-pl"><a href="https://pl.wikipedia.org/wiki/Obszary_metropolitalne_w_Stanach_Zjednoczonych" title="Obszary metropolitalne w Stanach Zjednoczonych – Polish" lang="pl" hreflang="pl" class="interlanguage-link-target">Polski</a></li><li class="uls-p-lang-dummy"><a href="#"></a></li>					</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q4387868#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 19 October 2016, at 01:30.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=List_of_Metropolitan_Statistical_Areas&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.loader.load(["ext.cite.a11y","mediawiki.toc","mediawiki.action.view.postEdit","site","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","mmv.bootstrap.autostart","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"]);});</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set( {
#     "wgPageParseReport": {
#         "limitreport": {
#             "cputime": "2.136",
#             "walltime": "2.216",
#             "ppvisitednodes": {
#                 "value": 109719,
#                 "limit": 1000000
#             },
#             "ppgeneratednodes": {
#                 "value": 0,
#                 "limit": 1500000
#             },
#             "postexpandincludesize": {
#                 "value": 707841,
#                 "limit": 2097152
#             },
#             "templateargumentsize": {
#                 "value": 155519,
#                 "limit": 2097152
#             },
#             "expansiondepth": {
#                 "value": 15,
#                 "limit": 40
#             },
#             "expensivefunctioncount": {
#                 "value": 0,
#                 "limit": 500
#             },
#             "entityaccesscount": {
#                 "value": 0,
#                 "limit": 400
#             },
#             "timingprofile": [
#                 "100.00% 1822.406      1 -total",
#                 " 65.19% 1187.955    389 Template:Change",
#                 " 61.83% 1126.789    389 Template:Change/rowIonSoff",
#                 " 46.16%  841.197    389 Template:Change/outIonSon",
#                 " 25.15%  458.284    389 Template:Nts",
#                 " 19.95%  363.526    388 Template:Ntsh",
#                 " 18.76%  341.872    389 Template:Number_table_sorting/Qno/Fyes/Sno/0",
#                 " 10.79%  196.636    302 Template:Number_table_sorting/Qyes/0",
#                 "  3.13%   57.069     86 Template:Number_table_sorting/Qyes/1",
#                 "  1.95%   35.524      1 Template:Reflist"
#             ]
#         },
#         "scribunto": {
#             "limitreport-timeusage": {
#                 "value": "0.317",
#                 "limit": "10.000"
#             },
#             "limitreport-memusage": {
#                 "value": 2529314,
#                 "limit": 52428800
#             }
#         },
#         "cachereport": {
#             "origin": "mw1236",
#             "timestamp": "20161019033135",
#             "ttl": 2592000,
#             "transientcontent": false
#         }
#     }
# } );});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":2330,"wgHostname":"mw1236"});});</script>
# 	</body>
# </html>
# []

# %%
cities = Selector(text=HTML_lc).xpath('//td/a/text()').extract()
cities
# Out:
# [u'Populous cities and metropolitan areas',
#  u'New York-Newark-Jersey City, NY-NJ-PA Metropolitan Statistical Area',
#  u'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#  u'Los Angeles-Long Beach-Anaheim, CA Metropolitan Statistical Area',
#  u'Los Angeles-Long Beach, CA Combined Statistical Area',
#  u'Chicago-Naperville-Elgin, IL-IN-WI Metropolitan Statistical Area',
#  u'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#  u'Dallas-Fort Worth-Arlington, TX Metropolitan Statistical Area',
#  u'Dallas-Fort Worth, TX-OK Combined Statistical Area',
#  u'Houston-The Woodlands-Sugar Land, TX Metropolitan Statistical Area',
#  u'Houston-The Woodlands, TX Combined Statistical Area',
#  u'Washington-Arlington-Alexandria, DC-VA-MD-WV Metropolitan Statistical Area',
#  u'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#  u'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Metropolitan Statistical Area',
#  u'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#  u'Miami-Fort Lauderdale-West Palm Beach, FL Metropolitan Statistical Area',
#  u'Miami-Fort Lauderdale-Port St. Lucie, FL Combined Statistical Area',
#  u'Atlanta-Sandy Springs-Roswell, GA Metropolitan Statistical Area',
#  u'Atlanta-Sandy Springs, GA Combined Statistical Area',
#  u'Boston-Cambridge-Newton, MA-NH Metropolitan Statistical Area',
#  u'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#  u'San Francisco\u2013Oakland\u2013Hayward, CA Metropolitan Statistical Area',
#  u'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#  u'Phoenix-Mesa-Scottsdale, AZ Metropolitan Statistical Area',
#  u'Riverside-San Bernardino-Ontario, CA Metropolitan Statistical Area',
#  u'Los Angeles-Long Beach, CA Combined Statistical Area',
#  u'Detroit-Warren-Dearborn, MI Metropolitan Statistical Area',
#  u'Detroit-Warren-Ann Arbor, MI Combined Statistical Area',
#  u'Seattle-Tacoma-Bellevue, WA Metropolitan Statistical Area',
#  u'Seattle-Tacoma, WA Combined Statistical Area',
#  u'Minneapolis-St. Paul-Bloomington, MN-WI Metropolitan Statistical Area',
#  u'Minneapolis-St. Paul, MN-WI Combined Statistical Area',
#  u'San Diego-Carlsbad, CA Metropolitan Statistical Area',
#  u'Tampa-St. Petersburg-Clearwater, FL Metropolitan Statistical Area',
#  u'Denver-Aurora-Lakewood, CO Metropolitan Statistical Area',
#  u'Denver-Aurora-Lakewood, CO Metropolitan Statistical Area',
#  u'St. Louis, MO-IL Metropolitan Statistical Area',
#  u'St. Louis-St. Charles-Farmington, MO-IL Combined Statistical Area',
#  u'Baltimore-Columbia-Towson, MD Metropolitan Statistical Area',
#  u'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#  u'Charlotte-Concord-Gastonia, NC-SC Metropolitan Statistical Area',
#  u'Charlotte-Concord, NC-SC Combined Statistical Area',
#  u'Portland-Vancouver-Hillsboro, OR-WA Metropolitan Statistical Area',
#  u'Portland-Vancouver-Salem, OR-WA Combined Statistical Area',
#  u'Orlando-Kissimmee-Sanford, FL Metropolitan Statistical Area',
#  u'Orlando-Deltona-Daytona Beach, FL Combined Statistical Area',
#  u'San Antonio-New Braunfels, TX Metropolitan Statistical Area',
#  u'Pittsburgh, PA Metropolitan Statistical Area',
#  u'Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area',
#  u'Sacramento\u2013Roseville\u2013Arden-Arcade, CA Metropolitan Statistical Area',
#  u'Sacramento-Roseville, CA Combined Statistical Area',
#  u'Cincinnati, OH-KY-IN Metropolitan Statistical Area',
#  u'Cincinnati-Wilmington-Maysville, OH-KY-IN Combined Statistical Area',
#  u'Las Vegas-Henderson-Paradise, NV Metropolitan Statistical Area',
#  u'Las Vegas-Henderson, NV-AZ Combined Statistical Area',
#  u'Kansas City, MO-KS Metropolitan Statistical Area',
#  u'Kansas City-Overland Park-Kansas City, MO-KS Combined Statistical Area',
#  u'Cleveland-Elyria, OH Metropolitan Statistical Area',
#  u'Cleveland-Akron-Canton, OH Combined Statistical Area',
#  u'Columbus, OH Metropolitan Statistical Area',
#  u'Columbus-Marion-Zanesville, OH Combined Statistical Area',
#  u'Austin-Round Rock, TX Metropolitan Statistical Area',
#  u'Indianapolis-Carmel-Anderson, IN Metropolitan Statistical Area',
#  u'Indianapolis-Carmel-Muncie, IN Combined Statistical Area',
#  u'San Jose-Sunnyvale-Santa Clara, CA Metropolitan Statistical Area',
#  u'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#  u'Nashville-Davidson\u2013Murfreesboro\u2013Franklin, TN Metropolitan Statistical Area',
#  u'Nashville-Davidson\u2013Murfreesboro, TN Combined Statistical Area',
#  u'Virginia Beach-Norfolk-Newport News, VA-NC Metropolitan Statistical Area',
#  u'Virginia Beach-Norfolk, VA-NC Combined Statistical Area',
#  u'Providence-Warwick, RI-MA Metropolitan Statistical Area',
#  u'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#  u'Milwaukee-Waukesha-West Allis, WI Metropolitan Statistical Area',
#  u'Milwaukee-Racine-Waukesha, WI Combined Statistical Area',
#  u'Jacksonville, FL Metropolitan Statistical Area',
#  u'Jacksonville-St. Marys-Palatka, FL-GA Combined Statistical Area',
#  u'Oklahoma City, OK Metropolitan Statistical Area',
#  u'Oklahoma City-Shawnee, OK Combined Statistical Area',
#  u'Memphis, TN-MS-AR Metropolitan Statistical Area',
#  u'Memphis-Forrest City, TN-MS-AR Combined Statistical Area',
#  u'Louisville/Jefferson County, KY-IN Metropolitan Statistical Area',
#  u'Louisville/Jefferson County\u2013Elizabethtown\u2013Madison, KY-IN Combined Statistical Area',
#  u'Raleigh, NC Metropolitan Statistical Area',
#  u'Raleigh-Durham-Chapel Hill, NC Combined Statistical Area',
#  u'Richmond, VA Metropolitan Statistical Area',
#  u'New Orleans-Metairie, LA Metropolitan Statistical Area',
#  u'New Orleans-Metairie-Hammond, LA-MS Combined Statistical Area',
#  u'Hartford-West Hartford-East Hartford, CT Metropolitan Statistical Area',
#  u'Hartford-West Hartford, CT Combined Statistical Area',
#  u'Salt Lake City, UT Metropolitan Statistical Area',
#  u'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#  u'Birmingham-Hoover, AL Metropolitan Statistical Area',
#  u'Birmingham-Hoover-Talladega, AL Combined Statistical Area',
#  u'Buffalo-Cheektowaga-Niagara Falls, NY Metropolitan Statistical Area',
#  u'Buffalo-Cheektowaga, NY Combined Statistical Area',
#  u'Rochester, NY Metropolitan Statistical Area',
#  u'Rochester-Batavia-Seneca Falls, NY Combined Statistical Area',
#  u'Grand Rapids-Wyoming, MI Metropolitan Statistical Area',
#  u'Grand Rapids-Wyoming-Muskegon, MI Combined Statistical Area',
#  u'Tucson, AZ Metropolitan Statistical Area',
#  u'Tucson-Nogales, AZ Combined Statistical Area',
#  u'Urban Honolulu, HI Metropolitan Statistical Area',
#  u'Tulsa, OK Metropolitan Statistical Area',
#  u'Tulsa-Muskogee-Bartlesville, OK Combined Statistical Area',
#  u'Fresno, CA Metropolitan Statistical Area',
#  u'Fresno-Madera, CA Combined Statistical Area',
#  u'Bridgeport-Stamford-Norwalk, CT Metropolitan Statistical Area',
#  u'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#  u'Worcester, MA-CT Metropolitan Statistical Area',
#  u'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#  u'Omaha-Council Bluffs, NE-IA Metropolitan Statistical Area',
#  u'Omaha-Council Bluffs-Fremont, NE-IA Combined Statistical Area',
#  u'Albuquerque, NM Metropolitan Statistical Area',
#  u'Albuquerque-Santa Fe-Las Vegas, NM Combined Statistical Area',
#  u'Bakersfield, CA Metropolitan Statistical Area',
#  u'Albany-Schenectady-Troy, NY Metropolitan Statistical Area',
#  u'Albany-Schenectady, NY Combined Statistical Area',
#  u'Greenville-Anderson-Mauldin, SC Metropolitan Statistical Area',
#  u'Greenville-Spartanburg-Anderson, SC Combined Statistical Area',
#  u'Knoxville, TN Metropolitan Statistical Area',
#  u'Knoxville-Morristown-Sevierville, TN Combined Statistical Area',
#  u'New Haven-Milford, CT Metropolitan Statistical Area',
#  u'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#  u'Oxnard-Thousand Oaks-Ventura, CA Metropolitan Statistical Area',
#  u'Los Angeles-Long Beach, CA Combined Statistical Area',
#  u'McAllen-Edinburg-Mission, TX Metropolitan Statistical Area',
#  u'McAllen-Edinburg, TX Combined Statistical Area',
#  u'El Paso, TX Metropolitan Statistical Area',
#  u'El Paso-Las Cruces, TX-NM Combined Statistical Area',
#  u'Allentown-Bethlehem-Easton, PA-NJ Metropolitan Statistical Area',
#  u'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#  u'Baton Rouge, LA Metropolitan Statistical Area',
#  u'Columbia, SC Metropolitan Statistical Area',
#  u'Columbia-Orangeburg-Newberry, SC Combined Statistical Area',
#  u'Dayton, OH Metropolitan Statistical Area',
#  u'Dayton-Springfield-Sidney, OH Combined Statistical Area',
#  u'North Port-Sarasota-Bradenton, FL Metropolitan Statistical Area',
#  u'North Port-Sarasota, FL Combined Statistical Area',
#  u'Greensboro-High Point, NC Metropolitan Statistical Area',
#  u'Greensboro\u2013Winston-Salem\u2013High Point, NC Combined Statistical Area',
#  u'Charleston-North Charleston, SC Metropolitan Statistical Area',
#  u'Little Rock-North Little Rock-Conway, AR Metropolitan Statistical Area',
#  u'Little Rock-North Little Rock, AR Combined Statistical Area',
#  u'Stockton-Lodi, CA Metropolitan Statistical Area',
#  u'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#  u'Akron, OH Metropolitan Statistical Area',
#  u'Cleveland-Akron-Canton, OH Combined Statistical Area',
#  u'Cape Coral-Fort Myers, FL Metropolitan Statistical Area',
#  u'Cape Coral-Fort Myers-Naples, FL Combined Statistical Area',
#  u'Colorado Springs, CO Metropolitan Statistical Area',
#  u'Boise City, ID Metropolitan Statistical Area',
#  u'Boise City-Mountain Home-Ontario, ID-OR Combined Statistical Area',
#  u'Syracuse, NY Metropolitan Statistical Area',
#  u'Syracuse-Auburn, NY Combined Statistical Area',
#  u'Winston-Salem, NC Metropolitan Statistical Area',
#  u'Greensboro\u2013Winston-Salem\u2013High Point, NC Combined Statistical Area',
#  u'Lakeland-Winter Haven, FL Metropolitan Statistical Area',
#  u'Toledo, OH Metropolitan Statistical Area',
#  u'Toledo-Port Clinton, OH Combined Statistical Area',
#  u'Wichita, KS Metropolitan Statistical Area',
#  u'Wichita-Arkansas City-Winfield, KS Combined Statistical Area',
#  u'Ogden-Clearfield, UT Metropolitan Statistical Area',
#  u'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#  u'Madison, WI Metropolitan Statistical Area',
#  u'Madison-Janesville-Beloit, WI Combined Statistical Area',
#  u'Springfield, MA Metropolitan Statistical Area',
#  u'Springfield-Greenfield Town, MA Combined Statistical Area',
#  u'Deltona-Daytona Beach-Ormond Beach, FL Metropolitan Statistical Area',
#  u'Orlando-Deltona-Daytona Beach, FL Combined Statistical Area',
#  u'Des Moines-West Des Moines, IA Metropolitan Statistical Area',
#  u'Des Moines-Ames-West Des Moines, IA Combined Statistical Area',
#  u'Augusta-Richmond County, GA-SC Metropolitan Statistical Area',
#  u'Provo-Orem, UT Metropolitan Statistical Area',
#  u'Salt Lake City-Provo-Orem, UT Combined Statistical Area',
#  u'Jackson, MS Metropolitan Statistical Area',
#  u'Jackson-Vicksburg-Brookhaven, MS Combined Statistical Area',
#  u'Palm Bay-Melbourne-Titusville, FL Metropolitan Statistical Area',
#  u'Harrisburg-Carlisle, PA Metropolitan Statistical Area',
#  u'Harrisburg-York-Lebanon, PA Combined Statistical Area',
#  u'Scranton\u2013Wilkes-Barre\u2013Hazleton, PA Metropolitan Statistical Area',
#  u'Durham-Chapel Hill, NC Metropolitan Statistical Area',
#  u'Raleigh-Durham-Chapel Hill, NC Combined Statistical Area',
#  u'Youngstown-Warren-Boardman, OH-PA Metropolitan Statistical Area',
#  u'Youngstown-Warren, OH-PA Combined Statistical Area',
#  u'Spokane-Spokane Valley, WA Metropolitan Statistical Area',
#  u"Spokane-Spokane Valley-Coeur d'Alene, WA-ID Combined Statistical Area",
#  u'Chattanooga, TN-GA Metropolitan Statistical Area',
#  u'Chattanooga-Cleveland-Dalton, TN-GA-AL Combined Statistical Area',
#  u'Modesto, CA Metropolitan Statistical Area',
#  u'Modesto-Merced, CA Combined Statistical Area',
#  u'Lancaster, PA Metropolitan Statistical Area',
#  u'Portland-South Portland, ME Metropolitan Statistical Area',
#  u'Portland-Lewiston-South Portland, ME Combined Statistical Area',
#  u'Fayetteville-Springdale-Rogers, AR-MO Metropolitan Statistical Area',
#  u'Santa Rosa, CA Metropolitan Statistical Area',
#  u'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#  u'Lexington-Fayette, KY Metropolitan Statistical Area',
#  u'Lexington-Fayette\u2013Richmond\u2013Frankfort, KY Combined Statistical Area',
#  u'Lafayette, LA Metropolitan Statistical Area',
#  u'Lafayette-Opelousas-Morgan City, LA Combined Statistical Area',
#  u'Pensacola-Ferry Pass-Brent, FL Metropolitan Statistical Area',
#  u'Lansing-East Lansing, MI Metropolitan Statistical Area',
#  u'Lansing-East Lansing-Owosso, MI Combined Statistical Area',
#  u'Visalia-Porterville, CA Metropolitan Statistical Area',
#  u'Visalia-Porterville-Hanford, CA Combined Statistical Area',
#  u'Springfield, MO Metropolitan Statistical Area',
#  u'Springfield-Branson, MO Combined Statistical Area',
#  u'Port St. Lucie, FL Metropolitan Statistical Area',
#  u'Miami-Fort Lauderdale-Port St. Lucie, FL Combined Statistical Area',
#  u'Corpus Christi, TX Metropolitan Statistical Area',
#  u'Corpus Christi-Kingsville-Alice, TX Combined Statistical Area',
#  u'Reno, NV Metropolitan Statistical Area',
#  u'Reno-Carson City-Fernley, NV Combined Statistical Area',
#  u'Asheville, NC Metropolitan Statistical Area',
#  u'Asheville-Brevard, NC Combined Statistical Area',
#  u'Santa Maria-Santa Barbara, CA Metropolitan Statistical Area',
#  u'Huntsville, AL Metropolitan Statistical Area',
#  u'Huntsville-Decatur-Albertville, AL Combined Statistical Area',
#  u'Shreveport-Bossier City, LA Metropolitan Statistical Area',
#  u'York-Hanover, PA Metropolitan Statistical Area',
#  u'Harrisburg-York-Lebanon, PA Combined Statistical Area',
#  u'Vallejo-Fairfield, CA Metropolitan Statistical Area',
#  u'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#  u'Salinas, CA Metropolitan Statistical Area',
#  u'Myrtle Beach-Conway-North Myrtle Beach, SC-NC Metropolitan Statistical Area',
#  u'Myrtle Beach-Conway, SC-NC Combined Statistical Area',
#  u'Killeen-Temple, TX Metropolitan Statistical Area',
#  u'Fort Wayne, IN Metropolitan Statistical Area',
#  u'Fort Wayne-Huntington-Auburn, IN Combined Statistical Area',
#  u'Brownsville-Harlingen, TX Metropolitan Statistical Area',
#  u'Brownsville-Harlingen-Raymondville, TX Combined Statistical Area',
#  u'Mobile, AL Metropolitan Statistical Area',
#  u'Mobile-Daphne-Fairhope, AL Combined Statistical Area',
#  u'Reading, PA Metropolitan Statistical Area',
#  u'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#  u'Flint, MI Metropolitan Statistical Area',
#  u'Detroit-Warren-Ann Arbor, MI Combined Statistical Area',
#  u'Salem, OR Metropolitan Statistical Area',
#  u'Portland-Vancouver-Salem, OR-WA Combined Statistical Area',
#  u'Beaumont-Port Arthur, TX Metropolitan Statistical Area',
#  u'Manchester-Nashua, NH Metropolitan Statistical Area',
#  u'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#  u'Canton-Massillon, OH Metropolitan Statistical Area',
#  u'Cleveland-Akron-Canton, OH Combined Statistical Area',
#  u'Anchorage, AK Metropolitan Statistical Area',
#  u'Salisbury, MD-DE Metropolitan Statistical Area',
#  u'Gulfport-Biloxi-Pascagoula, MS Metropolitan Statistical Area',
#  u'Davenport-Moline-Rock Island, IA-IL Metropolitan Statistical Area',
#  u'Davenport-Moline, IA-IL Combined Statistical Area',
#  u'Savannah, GA Metropolitan Statistical Area',
#  u'Savannah-Hinesville-Statesboro, GA Combined Statistical Area',
#  u'Peoria, IL Metropolitan Statistical Area',
#  u'Peoria-Canton, IL Combined Statistical Area',
#  u'Tallahassee, FL Metropolitan Statistical Area',
#  u'Tallahassee-Bainbridge, FL-GA Combined Statistical Area',
#  u'Fayetteville, NC Metropolitan Statistical Area',
#  u'Fayetteville-Lumberton-Laurinburg, NC Combined Statistical Area',
#  u'Montgomery, AL Metropolitan Statistical Area',
#  u'Trenton, NJ Metropolitan Statistical Area',
#  u'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#  u'Eugene, OR Metropolitan Statistical Area',
#  u'Hickory-Lenoir-Morganton, NC Metropolitan Statistical Area',
#  u'Hickory-Lenoir, NC Combined Statistical Area',
#  u'Huntington-Ashland, WV-KY-OH Metropolitan Statistical Area',
#  u'Charleston-Huntington-Ashland, WV-OH-KY Combined Statistical Area',
#  u'Ann Arbor, MI Metropolitan Statistical Area',
#  u'Detroit-Warren-Ann Arbor, MI Combined Statistical Area',
#  u'Naples-Immokalee-Marco Island, FL Metropolitan Statistical Area',
#  u'Cape Coral-Fort Myers-Naples, FL Combined Statistical Area',
#  u'Ocala, FL Metropolitan Statistical Area',
#  u'Rockford, IL Metropolitan Statistical Area',
#  u'Rockford-Freeport-Rochelle, IL Combined Statistical Area',
#  u'Kalamazoo-Portage, MI Metropolitan Statistical Area',
#  u'Kalamazoo-Battle Creek-Portage, MI Combined Statistical Area',
#  u'Fort Collins, CO Metropolitan Statistical Area',
#  u'Spartanburg, SC Metropolitan Statistical Area',
#  u'Greenville-Spartanburg-Anderson, SC Combined Statistical Area',
#  u'Lincoln, NE Metropolitan Statistical Area',
#  u'Lincoln-Beatrice, NE Combined Statistical Area',
#  u'South Bend-Mishawaka, IN-MI Metropolitan Statistical Area',
#  u'South Bend-Elkhart-Mishawaka, IN-MI Combined Statistical Area',
#  u'Boulder, CO Metropolitan Statistical Area',
#  u'Denver-Aurora, CO Combined Statistical Area',
#  u'Green Bay, WI Metropolitan Statistical Area',
#  u'Green Bay-Shawano, WI Combined Statistical Area',
#  u'Evansville, IN-KY Metropolitan Statistical Area',
#  u'Roanoke, VA Metropolitan Statistical Area',
#  u'Columbus, GA-AL Metropolitan Statistical Area',
#  u'Columbus-Auburn-Opelika, GA-AL Combined Statistical Area',
#  u'Lubbock, TX Metropolitan Statistical Area',
#  u'Lubbock-Levelland, TX Combined Statistical Area',
#  u'Kingsport-Bristol-Bristol, TN-VA Metropolitan Statistical Area',
#  u'Johnson City-Kingsport-Bristol, TN-VA Combined Statistical Area',
#  u'Utica-Rome, NY Metropolitan Statistical Area',
#  u'Greeley, CO Metropolitan Statistical Area',
#  u'Denver-Aurora, CO Combined Statistical Area',
#  u'San Luis Obispo-Paso Robles-Arroyo Grande, CA Metropolitan Statistical Area',
#  u'Clarksville, TN-KY Metropolitan Statistical Area',
#  u'Fort Smith, AR-OK Metropolitan Statistical Area',
#  u'Duluth, MN-WI Metropolitan Statistical Area',
#  u'Kennewick-Richland, WA Metropolitan Statistical Area',
#  u'Erie, PA Metropolitan Statistical Area',
#  u'Erie-Meadville, PA Combined Statistical Area',
#  u'Wilmington, NC Metropolitan Statistical Area',
#  u'Gainesville, FL Metropolitan Statistical Area',
#  u'Gainesville-Lake City, FL Combined Statistical Area',
#  u'Atlantic City-Hammonton, NJ Metropolitan Statistical Area',
#  u'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#  u'Santa Cruz-Watsonville, CA Metropolitan Statistical Area',
#  u'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#  u'Norwich-New London, CT Metropolitan Statistical Area',
#  u'Hartford-West Hartford, CT Combined Statistical Area',
#  u'Laredo, TX Metropolitan Statistical Area',
#  u'Olympia-Tumwater, WA Metropolitan Statistical Area',
#  u'Seattle-Tacoma, WA Combined Statistical Area',
#  u'Merced, CA Metropolitan Statistical Area',
#  u'Modesto-Merced, CA Combined Statistical Area',
#  u'Cedar Rapids, IA Metropolitan Statistical Area',
#  u'Cedar Rapids-Iowa City, IA Combined Statistical Area',
#  u'Waco, TX Metropolitan Statistical Area',
#  u'Crestview-Fort Walton Beach-Destin, FL Metropolitan Statistical Area',
#  u'Amarillo, TX Metropolitan Statistical Area',
#  u'Amarillo-Borger, TX Combined Statistical Area',
#  u'Hagerstown-Martinsburg, MD-WV Metropolitan Statistical Area',
#  u'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#  u'Bremerton-Silverdale, WA Metropolitan Statistical Area',
#  u'Seattle-Tacoma, WA Combined Statistical Area',
#  u'Lynchburg, VA Metropolitan Statistical Area',
#  u'Sioux Falls, SD Metropolitan Statistical Area',
#  u'College Station-Bryan, TX Metropolitan Statistical Area',
#  u'Yakima, WA Metropolitan Statistical Area',
#  u'Binghamton, NY Metropolitan Statistical Area',
#  u'Tuscaloosa, AL Metropolitan Statistical Area',
#  u'Champaign-Urbana, IL Metropolitan Statistical Area',
#  u'Fargo, ND-MN Metropolitan Statistical Area',
#  u'Fargo-Wahpeton, ND-MN Combined Statistical Area',
#  u'Topeka, KS Metropolitan Statistical Area',
#  u'Appleton, WI Metropolitan Statistical Area',
#  u'Appleton-Oshkosh-Neenah, WI Combined Statistical Area',
#  u'Macon, GA Metropolitan Statistical Area',
#  u'Macon-Warner Robins, GA Combined Statistical Area',
#  u'Charlottesville, VA Metropolitan Statistical Area',
#  u'Chico, CA Metropolitan Statistical Area',
#  u'Tyler, TX Metropolitan Statistical Area',
#  u'Tyler-Jacksonville, TX Combined Statistical Area',
#  u'Prescott, AZ Metropolitan Statistical Area',
#  u'Charleston, WV Metropolitan Statistical Area',
#  u'Charleston-Huntington-Ashland, WV-OH-KY Combined Statistical Area',
#  u'Longview, TX Metropolitan Statistical Area',
#  u'Longview-Marshall, TX Combined Statistical Area',
#  u'Burlington-South Burlington, VT Metropolitan Statistical Area',
#  u'Lafayette-West Lafayette, IN Metropolitan Statistical Area',
#  u'Lafayette-West Lafayette-Frankfort, IN Combined Statistical Area',
#  u'Barnstable Town, MA Metropolitan Statistical Area',
#  u'Boston-Worcester-Providence, MA-RI-NH-CT Combined Statistical Area',
#  u'Las Cruces, NM Metropolitan Statistical Area',
#  u'El Paso-Las Cruces, TX-NM Combined Statistical Area',
#  u'Rochester, MN Metropolitan Statistical Area',
#  u'Rochester-Austin, MN Combined Statistical Area',
#  u'Medford, OR Metropolitan Statistical Area',
#  u'Medford-Grants Pass, OR Combined Statistical Area',
#  u'Houma-Thibodaux, LA Metropolitan Statistical Area',
#  u'Bellingham, WA Metropolitan Statistical Area',
#  u'Springfield, IL Metropolitan Statistical Area',
#  u'Springfield-Jacksonville-Lincoln, IL Combined Statistical Area',
#  u'Hilton Head Island-Bluffton-Beaufort, SC Metropolitan Statistical Area',
#  u'Florence, SC Metropolitan Statistical Area',
#  u'Lake Charles, LA Metropolitan Statistical Area',
#  u'Lake Havasu City-Kingman, AZ Metropolitan Statistical Area',
#  u'Las Vegas-Henderson, NV-AZ Combined Statistical Area',
#  u'Yuma, AZ Metropolitan Statistical Area',
#  u'Daphne-Fairhope-Foley, AL Metropolitan Statistical Area',
#  u'Mobile-Daphne-Fairhope, AL Combined Statistical Area',
#  u'Elkhart-Goshen, IN Metropolitan Statistical Area',
#  u'South Bend-Elkhart-Mishawaka, IN-MI Combined Statistical Area',
#  u'Athens-Clarke County, GA Metropolitan Statistical Area',
#  u'Atlanta\u2013Athens-Clarke County\u2013Sandy Springs, GA Combined Statistical Area',
#  u'Johnson City, TN Metropolitan Statistical Area',
#  u'Johnson City-Kingsport-Bristol, TN-VA Combined Statistical Area',
#  u'Panama City, FL Metropolitan Statistical Area',
#  u'Racine, WI Metropolitan Statistical Area',
#  u'Milwaukee-Racine-Waukesha, WI Combined Statistical Area',
#  u'St. Cloud, MN Metropolitan Statistical Area',
#  u'Minneapolis-St. Paul, MN-WI Combined Statistical Area',
#  u'Gainesville, GA Metropolitan Statistical Area',
#  u'Atlanta\u2013Athens-Clarke County\u2013Sandy Springs, GA Combined Statistical Area',
#  u'Saginaw, MI Metropolitan Statistical Area',
#  u'Saginaw-Midland-Bay City, MI Combined Statistical Area',
#  u'Bloomington, IL Metropolitan Statistical Area',
#  u'Bloomington-Pontiac, IL Combined Statistical Area',
#  u'Warner Robins, GA Metropolitan Statistical Area',
#  u'Macon-Warner Robins, GA Combined Statistical Area',
#  u'Jacksonville, NC Metropolitan Statistical Area',
#  u'Blacksburg-Christiansburg-Radford, VA Metropolitan Statistical Area',
#  u'El Centro, CA Metropolitan Statistical Area',
#  u'Kingston, NY Metropolitan Statistical Area',
#  u'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#  u'Redding, CA Metropolitan Statistical Area',
#  u'Redding-Red Bluff, CA Combined Statistical Area',
#  u'Monroe, LA Metropolitan Statistical Area',
#  u'Monroe-Ruston-Bastrop, LA Combined Statistical Area',
#  u'Joplin, MO Metropolitan Statistical Area',
#  u'Joplin-Miami, MO-OK Combined Statistical Area',
#  u'Greenville, NC Metropolitan Statistical Area',
#  u'Greenville-Washington, NC Combined Statistical Area',
#  u'Bend-Redmond, OR Metropolitan Statistical Area',
#  u'Bend-Redmond-Prineville, OR Combined Statistical Area',
#  u'Columbia, MO Metropolitan Statistical Area',
#  u'Columbia-Moberly-Mexico, MO Combined Statistical Area',
#  u'Dover, DE Metropolitan Statistical Area',
#  u'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#  u'Punta Gorda, FL Metropolitan Statistical Area',
#  u'North Port-Sarasota, FL Combined Statistical Area',
#  u'Muskegon, MI Metropolitan Statistical Area',
#  u'Grand Rapids-Wyoming-Muskegon, MI Combined Statistical Area',
#  u'Terre Haute, IN Metropolitan Statistical Area',
#  u'Yuba City, CA Metropolitan Statistical Area',
#  u'Sacramento-Roseville, CA Combined Statistical Area',
#  u'Waterloo-Cedar Falls, IA Metropolitan Statistical Area',
#  u'Abilene, TX Metropolitan Statistical Area',
#  u'Oshkosh-Neenah, WI Metropolitan Statistical Area',
#  u'Appleton-Oshkosh-Neenah, WI Combined Statistical Area',
#  u'Sioux City, IA-NE-SD Metropolitan Statistical Area',
#  u'Sioux City-Vermillion, IA-SD-NE Combined Statistical Area',
#  u'Bowling Green, KY Metropolitan Statistical Area',
#  u'Bowling Green-Glasgow, KY Combined Statistical Area',
#  u'Billings, MT Metropolitan Statistical Area',
#  u'Midland, TX Metropolitan Statistical Area',
#  u'Midland-Odessa, TX Combined Statistical Area',
#  u'Iowa City, IA Metropolitan Statistical Area',
#  u'Cedar Rapids-Iowa City, IA Combined Statistical Area',
#  u'East Stroudsburg, PA Metropolitan Statistical Area',
#  u'New York-Newark, NY-NJ-CT-PA Combined Statistical Area',
#  u'Eau Claire, WI Metropolitan Statistical Area',
#  u'Eau Claire-Menomonie, WI Combined Statistical Area',
#  u'Bloomington, IN Metropolitan Statistical Area',
#  u'Bloomington-Bedford, IN Combined Statistical Area',
#  u'Kahului-Wailuku-Lahaina, HI Metropolitan Statistical Area',
#  u'Pueblo, CO Metropolitan Statistical Area',
#  u'Pueblo-Ca\xf1on City, CO Combined Statistical Area',
#  u'Janesville-Beloit, WI Metropolitan Statistical Area',
#  u'Madison-Janesville-Beloit, WI Combined Statistical Area',
#  u'State College, PA Metropolitan Statistical Area',
#  u'State College-DuBois, PA Combined Statistical Area',
#  u'Jackson, MI Metropolitan Statistical Area',
#  u'Odessa, TX Metropolitan Statistical Area',
#  u'Midland-Odessa, TX Combined Statistical Area',
#  u'Burlington, NC Metropolitan Statistical Area',
#  u'Greensboro\u2013Winston-Salem\u2013High Point, NC Combined Statistical Area',
#  u'Auburn-Opelika, AL Metropolitan Statistical Area',
#  u'Columbus-Auburn-Opelika, GA-AL Combined Statistical Area',
#  u'Vineland-Bridgeton, NJ Metropolitan Statistical Area',
#  u'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#  u'St. George, UT Metropolitan Statistical Area',
#  u'Madera, CA Metropolitan Statistical Area',
#  u'Fresno-Madera, CA Combined Statistical Area',
#  u'Niles-Benton Harbor, MI Metropolitan Statistical Area',
#  u'South Bend-Elkhart-Mishawaka, IN-MI Combined Statistical Area',
#  u'Alexandria, LA Metropolitan Statistical Area',
#  u'Chambersburg-Waynesboro, PA Metropolitan Statistical Area',
#  u'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#  u'Albany, GA Metropolitan Statistical Area',
#  u'Bangor, ME Metropolitan Statistical Area',
#  u'Decatur, AL Metropolitan Statistical Area',
#  u'Huntsville-Decatur-Albertville, AL Combined Statistical Area',
#  u'Jefferson City, MO Metropolitan Statistical Area',
#  u'Hanford-Corcoran, CA Metropolitan Statistical Area',
#  u'Visalia-Porterville-Hanford, CA Combined Statistical Area',
#  u'Wichita Falls, TX Metropolitan Statistical Area',
#  u"Coeur d'Alene, ID Metropolitan Statistical Area",
#  u"Spokane-Spokane Valley-Coeur d'Alene, WA-ID Combined Statistical Area",
#  u'Texarkana, TX-AR Metropolitan Statistical Area',
#  u'Monroe, MI Metropolitan Statistical Area',
#  u'Detroit-Warren-Ann Arbor, MI Combined Statistical Area',
#  u'Hattiesburg, MS Metropolitan Statistical Area',
#  u'Santa Fe, NM Metropolitan Statistical Area',
#  u'Albuquerque-Santa Fe-Las Vegas, NM Combined Statistical Area',
#  u'Elizabethtown-Fort Knox, KY Metropolitan Statistical Area',
#  u'Louisville/Jefferson County\u2013Elizabethtown\u2013Madison, KY-IN Combined Statistical Area',
#  u'Grand Junction, CO Metropolitan Statistical Area',
#  u'Dothan, AL Metropolitan Statistical Area',
#  u'Dothan-Enterprise-Ozark, AL Combined Statistical Area',
#  u'Rocky Mount, NC Metropolitan Statistical Area',
#  u'Rocky Mount-Wilson-Roanoke Rapids, NC Combined Statistical Area',
#  u'Sebastian-Vero Beach, FL Metropolitan Statistical Area',
#  u'Miami-Fort Lauderdale-Port St. Lucie, FL Combined Statistical Area',
#  u'Florence-Muscle Shoals, AL Metropolitan Statistical Area',
#  u'Wheeling, WV-OH Metropolitan Statistical Area',
#  u'Rapid City, SD Metropolitan Statistical Area',
#  u'Rapid City-Spearfish, SD Combined Statistical Area',
#  u'Dalton, GA Metropolitan Statistical Area',
#  u'Chattanooga-Cleveland-Dalton, TN-GA-AL Combined Statistical Area',
#  u'Valdosta, GA Metropolitan Statistical Area',
#  u'Napa, CA Metropolitan Statistical Area',
#  u'San Jose-San Francisco-Oakland, CA Combined Statistical Area',
#  u'Homosassa Springs, FL Metropolitan Statistical Area',
#  u'Idaho Falls, ID Metropolitan Statistical Area',
#  u'Idaho Falls-Rexburg-Blackfoot, ID Combined Statistical Area',
#  u'Flagstaff, AZ Metropolitan Statistical Area',
#  u'Morgantown, WV Metropolitan Statistical Area',
#  u'Morgantown-Fairmont, WV Combined Statistical Area',
#  u'Lebanon, PA Metropolitan Statistical Area',
#  u'Harrisburg-York-Lebanon, PA Combined Statistical Area',
#  u'La Crosse-Onalaska, WI-MN Metropolitan Statistical Area',
#  u'Johnstown, PA Metropolitan Statistical Area',
#  u'Johnstown-Somerset, PA Combined Statistical Area',
#  u'Springfield, OH Metropolitan Statistical Area',
#  u'Dayton-Springfield-Sidney, OH Combined Statistical Area',
#  u'Wausau, WI Metropolitan Statistical Area',
#  u'Wausau-Stevens Point-Wisconsin Rapids, WI Combined Statistical Area',
#  u'Battle Creek, MI Metropolitan Statistical Area',
#  u'Kalamazoo-Battle Creek-Portage, MI Combined Statistical Area',
#  u'Logan, UT-ID Metropolitan Statistical Area',
#  u'Winchester, VA-WV Metropolitan Statistical Area',
#  u'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#  u'Harrisonburg, VA Metropolitan Statistical Area',
#  u'Harrisonburg-Staunton-Waynesboro, VA Combined Statistical Area',
#  u'Lawton, OK Metropolitan Statistical Area',
#  u'Jackson, TN Metropolitan Statistical Area',
#  u'Bismarck, ND Metropolitan Statistical Area',
#  u'Hammond, LA Metropolitan Statistical Area',
#  u'New Orleans-Metairie-Hammond, LA-MS Combined Statistical Area',
#  u'Jonesboro, AR Metropolitan Statistical Area',
#  u'Jonesboro-Paragould, AR Combined Statistical Area',
#  u'Pittsfield, MA Metropolitan Statistical Area',
#  u'Glens Falls, NY Metropolitan Statistical Area',
#  u'Albany-Schenectady, NY Combined Statistical Area',
#  u'St. Joseph, MO-KS Metropolitan Statistical Area',
#  u'Kansas City-Overland Park-Kansas City, MO-KS Combined Statistical Area',
#  u'Carbondale-Marion, IL Metropolitan Statistical Area',
#  u'Sierra Vista-Douglas, AZ Metropolitan Statistical Area',
#  u'New Bern, NC Metropolitan Statistical Area',
#  u'New Bern-Morehead City, NC Combined Statistical Area',
#  u'Altoona, PA Metropolitan Statistical Area',
#  u'Sherman-Denison, TX Metropolitan Statistical Area',
#  u'Dallas-Fort Worth, TX-OK Combined Statistical Area',
#  u'Goldsboro, NC Metropolitan Statistical Area',
#  u'Beckley, WV Metropolitan Statistical Area',
#  u'Mount Vernon-Anacortes, WA Metropolitan Statistical Area',
#  u'Seattle-Tacoma, WA Combined Statistical Area',
#  u'Mansfield, OH Metropolitan Statistical Area',
#  u'Mansfield-Ashland-Bucyrus, OH Combined Statistical Area',
#  u'Cleveland, TN Metropolitan Statistical Area',
#  u'Chattanooga-Cleveland-Dalton, TN-GA-AL Combined Statistical Area',
#  u'Albany, OR Metropolitan Statistical Area',
#  u'Portland-Vancouver-Salem, OR-WA Combined Statistical Area',
#  u'Weirton-Steubenville, WV-OH Metropolitan Statistical Area',
#  u'Pittsburgh-New Castle-Weirton, PA-OH-WV Combined Statistical Area',
#  u'Staunton-Waynesboro, VA Metropolitan Statistical Area',
#  u'Harrisonburg-Staunton-Waynesboro, VA Combined Statistical Area',
#  u'San Angelo, TX Metropolitan Statistical Area',
#  u'The Villages, FL Metropolitan Statistical Area',
#  u'Orlando-Deltona-Daytona Beach, FL Combined Statistical Area',
#  u'Farmington, NM Metropolitan Statistical Area',
#  u'Lawrence, KS Metropolitan Statistical Area',
#  u'Kansas City-Overland Park-Kansas City, MO-KS Combined Statistical Area',
#  u'Watertown-Fort Drum, NY Metropolitan Statistical Area',
#  u'Owensboro, KY Metropolitan Statistical Area',
#  u'Muncie, IN Metropolitan Statistical Area',
#  u'Indianapolis-Carmel-Muncie, IN Combined Statistical Area',
#  u'Morristown, TN Metropolitan Statistical Area',
#  u'Knoxville-Morristown-Sevierville, TN Combined Statistical Area',
#  u'Wenatchee, WA Metropolitan Statistical Area',
#  u'Williamsport, PA Metropolitan Statistical Area',
#  u'Williamsport-Lock Haven, PA Combined Statistical Area',
#  u'Brunswick, GA Metropolitan Statistical Area',
#  u'Anniston-Oxford-Jacksonville, AL Metropolitan Statistical Area',
#  u'Sheboygan, WI Metropolitan Statistical Area',
#  u'Missoula, MT Metropolitan Statistical Area',
#  u'California-Lexington Park, MD Metropolitan Statistical Area',
#  u'Washington-Baltimore-Arlington, DC-MD-VA-WV-PA Combined Statistical Area',
#  u'Michigan City-La Porte, IN Metropolitan Statistical Area',
#  u'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#  u'Kankakee, IL Metropolitan Statistical Area',
#  u'Chicago-Naperville, IL-IN-WI Combined Statistical Area',
#  u'Sumter, SC Metropolitan Statistical Area',
#  u'Decatur, IL Metropolitan Statistical Area',
#  u'Lewiston-Auburn, ME Metropolitan Statistical Area',
#  u'Portland-Lewiston-South Portland, ME Combined Statistical Area',
#  u'Bay City, MI Metropolitan Statistical Area',
#  u'Saginaw-Midland-Bay City, MI Combined Statistical Area',
#  u'Ithaca, NY Metropolitan Statistical Area',
#  u'Ithaca-Cortland, NY Combined Statistical Area',
#  u'Lima, OH Metropolitan Statistical Area',
#  u'Lima-Van Wert-Celina, OH Combined Statistical Area',
#  u'Longview, WA Metropolitan Statistical Area',
#  u'Portland-Vancouver-Salem, OR-WA Combined Statistical Area',
#  u'Gadsden, AL Metropolitan Statistical Area',
#  u'Grand Forks, ND-MN Metropolitan Statistical Area',
#  u'Gettysburg, PA Metropolitan Statistical Area',
#  u'Harrisburg-York-Lebanon, PA Combined Statistical Area',
#  u'Fond du Lac, WI Metropolitan Statistical Area',
#  u'Cumberland, MD-WV Metropolitan Statistical Area',
#  u'Victoria, TX Metropolitan Statistical Area',
#  u'Victoria-Port Lavaca, TX Combined Statistical Area',
#  u'Fairbanks, AK Metropolitan Statistical Area',
#  u'Sebring, FL Metropolitan Statistical Area',
#  u'Mankato-North Mankato, MN Metropolitan Statistical Area',
#  u'Mankato-New Ulm-North Mankato, MN Combined Statistical Area',
#  u'Manhattan, KS Metropolitan Statistical Area',
#  u'Manhattan-Junction City, KS Combined Statistical Area',
#  u'Cape Girardeau, MO-IL Metropolitan Statistical Area',
#  u'Cape Girardeau-Sikeston, MO-IL Combined Statistical Area',
#  u'Hot Springs, AR Metropolitan Statistical Area',
#  u'Hot Springs-Malvern, AR Combined Statistical Area',
#  u'Dubuque, IA Metropolitan Statistical Area',
#  u'Cheyenne, WY Metropolitan Statistical Area',
#  u'Rome, GA Metropolitan Statistical Area',
#  u'Rome-Summerville, GA Combined Statistical Area',
#  u'Ames, IA Metropolitan Statistical Area',
#  u'Des Moines-Ames-West Des Moines, IA Combined Statistical Area',
#  u'Ocean City, NJ Metropolitan Statistical Area',
#  u'Philadelphia-Reading-Camden, PA-NJ-DE-MD Combined Statistical Area',
#  u'Pine Bluff, AR Metropolitan Statistical Area',
#  u'Little Rock-North Little Rock, AR Combined Statistical Area',
#  u'Parkersburg-Vienna, WV Metropolitan Statistical Area',
#  u'Parkersburg-Marietta-Vienna, WV-OH Combined Statistical Area',
#  u'Corvallis, OR Metropolitan Statistical Area',
#  u'Portland-Vancouver-Salem, OR-WA Combined Statistical Area',
#  u'Elmira, NY Metropolitan Statistical Area',
#  u'Elmira-Corning, NY Combined Statistical Area',
#  u'Bloomsburg-Berwick, PA Metropolitan Statistical Area',
#  u'Bloomsburg-Berwick-Sunbury, PA Combined Statistical Area',
#  u'Grand Island, NE Metropolitan Statistical Area',
#  u'Grants Pass, OR Metropolitan Statistical Area',
#  u'Medford-Grants Pass, OR Combined Statistical Area',
#  u'Pocatello, ID Metropolitan Statistical Area',
#  u'Midland, MI Metropolitan Statistical Area',
#  u'Saginaw-Midland-Bay City, MI Combined Statistical Area',
#  u'Kokomo, IN Metropolitan Statistical Area',
#  u'Kokomo-Peru, IN Combined Statistical Area',
#  u'Great Falls, MT Metropolitan Statistical Area',
#  u'Casper, WY Metropolitan Statistical Area',
#  u'Columbus, IN Metropolitan Statistical Area',
#  u'Indianapolis-Carmel-Muncie, IN Combined Statistical Area',
#  u'Hinesville, GA Metropolitan Statistical Area',
#  u'Savannah-Hinesville-Statesboro, GA Combined Statistical Area',
#  u'Danville, IL Metropolitan Statistical Area',
#  u'Walla Walla, WA Metropolitan Statistical Area',
#  u'Enid, OK Metropolitan Statistical Area',
#  u'Lewiston, ID-WA Metropolitan Statistical Area',
#  u'Carson City, NV Metropolitan Statistical Area',
#  u'Reno-Carson City-Fernley, NV Combined Statistical Area',
#  u'San Juan-Carolina-Caguas, PR Metropolitan Statistical Area',
#  u'San Juan-Carolina, PR Combined Statistical Area',
#  u'Ponce, PR Metropolitan Statistical Area',
#  u'Ponce-Coamo-Santa Isabel, PR Combined Statistical Area',
#  u'Aguadilla-Isabela, PR Metropolitan Statistical Area',
#  u'Arecibo, PR Metropolitan Statistical Area',
#  u'San Juan-Carolina, PR Combined Statistical Area',
#  u'San Germ\xe1n, PR Metropolitan Statistical Area',
#  u'Mayag\xfcez-San Germ\xe1n, PR Combined Statistical Area',
#  u'Mayag\xfcez, PR Metropolitan Statistical Area',
#  u'Mayag\xfcez-San Germ\xe1n, PR Combined Statistical Area',
#  u'Guayama, PR Metropolitan Statistical Area',
#  u'San Juan-Carolina, PR Combined Statistical Area',
#  u'Definitions',
#  u'Media',
#  u'News',
#  u'Quotations',
#  u'Texts',
#  u'Textbooks',
#  u'Learning resources']

# %%
cities = pd.DataFrame(cities)
cities = cities[0].head(25)
cities
# Out:
# 0                Populous cities and metropolitan areas
# 1     New York-Newark-Jersey City, NY-NJ-PA Metropol...
# 2     New York-Newark, NY-NJ-CT-PA Combined Statisti...
# 3     Los Angeles-Long Beach-Anaheim, CA Metropolita...
# 4     Los Angeles-Long Beach, CA Combined Statistica...
# 5     Chicago-Naperville-Elgin, IL-IN-WI Metropolita...
# 6     Chicago-Naperville, IL-IN-WI Combined Statisti...
# 7     Dallas-Fort Worth-Arlington, TX Metropolitan S...
# 8     Dallas-Fort Worth, TX-OK Combined Statistical ...
# 9     Houston-The Woodlands-Sugar Land, TX Metropoli...
# 10    Houston-The Woodlands, TX Combined Statistical...
# 11    Washington-Arlington-Alexandria, DC-VA-MD-WV M...
# 12    Washington-Baltimore-Arlington, DC-MD-VA-WV-PA...
# 13    Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
# 14    Philadelphia-Reading-Camden, PA-NJ-DE-MD Combi...
# 15    Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 16    Miami-Fort Lauderdale-Port St. Lucie, FL Combi...
# 17    Atlanta-Sandy Springs-Roswell, GA Metropolitan...
# 18    Atlanta-Sandy Springs, GA Combined Statistical...
# 19    Boston-Cambridge-Newton, MA-NH Metropolitan St...
# 20    Boston-Worcester-Providence, MA-RI-NH-CT Combi...
# 21    San Francisco–Oakland–Hayward, CA Metropolitan...
# 22    San Jose-San Francisco-Oakland, CA Combined St...
# 23    Phoenix-Mesa-Scottsdale, AZ Metropolitan Stati...
# 24    Riverside-San Bernardino-Ontario, CA Metropoli...
# Name: 0, dtype: object

# %%
cities = pd.DataFrame(cities)
cities.columns = ['city']
cities
# Out:
#                                                  city
# 0              Populous cities and metropolitan areas
# 1   New York-Newark-Jersey City, NY-NJ-PA Metropol...
# 2   New York-Newark, NY-NJ-CT-PA Combined Statisti...
# 3   Los Angeles-Long Beach-Anaheim, CA Metropolita...
# 4   Los Angeles-Long Beach, CA Combined Statistica...
# 5   Chicago-Naperville-Elgin, IL-IN-WI Metropolita...
# 6   Chicago-Naperville, IL-IN-WI Combined Statisti...
# 7   Dallas-Fort Worth-Arlington, TX Metropolitan S...
# 8   Dallas-Fort Worth, TX-OK Combined Statistical ...
# 9   Houston-The Woodlands-Sugar Land, TX Metropoli...
# 10  Houston-The Woodlands, TX Combined Statistical...
# 11  Washington-Arlington-Alexandria, DC-VA-MD-WV M...
# 12  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA...
# 13  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...
# 14  Philadelphia-Reading-Camden, PA-NJ-DE-MD Combi...
# 15  Miami-Fort Lauderdale-West Palm Beach, FL Metr...
# 16  Miami-Fort Lauderdale-Port St. Lucie, FL Combi...
# 17  Atlanta-Sandy Springs-Roswell, GA Metropolitan...
# 18  Atlanta-Sandy Springs, GA Combined Statistical...
# 19  Boston-Cambridge-Newton, MA-NH Metropolitan St...
# 20  Boston-Worcester-Providence, MA-RI-NH-CT Combi...
# 21  San Francisco–Oakland–Hayward, CA Metropolitan...
# 22  San Jose-San Francisco-Oakland, CA Combined St...
# 23  Phoenix-Mesa-Scottsdale, AZ Metropolitan Stati...
# 24  Riverside-San Bernardino-Ontario, CA Metropoli...

# %%
#cities.city
#cities = cities['city'].apply(lambda x: pd.Series(x.split(',-')))
cities.columns = ['city', 'state']

# %%
cities = cities.drop_duplicates(subset=0)
cities = cities.drop([0])
cities = cities[0]

# %%
cities = pd.DataFrame(cities)
cities.loc[21] = 'Sfbay'
cities
# Out:
#                0
# 1       New York
# 3    Los Angeles
# 5        Chicago
# 7         Dallas
# 9        Houston
# 11    Washington
# 13  Philadelphia
# 15         Miami
# 17       Atlanta
# 19        Boston
# 21         Sfbay
# 22      San Jose
# 23       Phoenix
# 24     Riverside

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1.2 Only retain cities with properly formed ASCII
#
# Optionally, filter out any cities with impropper ASCII characters.  A smaller list will be easier to look at.  However you may not need to filter these if you spend more time scraping a more concise city list.  This list should help you narrow down the list of regional Craigslist sites.

# %%
# ONLY RETAIN PROPERLY FORMED CITIES WITH FILTERING FUNCTION

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2.  Write a function to capture current pricing information via Craigslist in one city.
# Choose a city from your scraped data, then go to the cooresponding city section on Craigslist, searching for "rv" in the auto section.  Write a method that pulls out the prices.

# %%
from bs4 import BeautifulSoup as soup

# %%
response = requests.get("http://newyork.craigslist.org/search/sss?sort=rel&query=rv")
HTML = response.text
Selector(text=HTML).xpath('//span[@class="price"]/text()').extract()
# Out:
# [u'$19999',
#  u'$19999',
#  u'$15000',
#  u'$15000',
#  u'$3000',
#  u'$3000',
#  u'$55',
#  u'$55',
#  u'$350',
#  u'$350',
#  u'$75',
#  u'$75',
#  u'$18000',
#  u'$18000',
#  u'$5800',
#  u'$5800',
#  u'$2000',
#  u'$2000',
#  u'$3000',
#  u'$3000',
#  u'$3000',
#  u'$3000',
#  u'$310',
#  u'$310',
#  u'$75',
#  u'$75',
#  u'$2507',
#  u'$2507',
#  u'$325',
#  u'$325',
#  u'$2000',
#  u'$2000',
#  u'$25',
#  u'$25',
#  u'$2000',
#  u'$2000',
#  u'$3020',
#  u'$3020',
#  u'$3002',
#  u'$3002',
#  u'$6800',
#  u'$6800',
#  u'$85',
#  u'$85',
#  u'$85',
#  u'$85',
#  u'$2000',
#  u'$2000',
#  u'$82500',
#  u'$82500',
#  u'$8900',
#  u'$8900',
#  u'$9000',
#  u'$9000',
#  u'$3025',
#  u'$3025',
#  u'$3010',
#  u'$3010',
#  u'$3020',
#  u'$3020',
#  u'$1700',
#  u'$1700',
#  u'$325',
#  u'$325',
#  u'$2000',
#  u'$2000',
#  u'$15000',
#  u'$15000',
#  u'$750',
#  u'$750',
#  u'$450',
#  u'$450',
#  u'$64000',
#  u'$64000',
#  u'$8995',
#  u'$8995',
#  u'$100',
#  u'$100',
#  u'$135000',
#  u'$135000',
#  u'$2300',
#  u'$2300',
#  u'$7',
#  u'$7',
#  u'$8',
#  u'$8',
#  u'$26000',
#  u'$26000',
#  u'$1',
#  u'$1',
#  u'$23012',
#  u'$23012',
#  u'$340',
#  u'$340',
#  u'$6000',
#  u'$6000',
#  u'$7000',
#  u'$7000',
#  u'$8000',
#  u'$8000',
#  u'$6900',
#  u'$6900',
#  u'$3321',
#  u'$3321',
#  u'$425',
#  u'$425',
#  u'$425',
#  u'$425',
#  u'$2003',
#  u'$2003',
#  u'$2000',
#  u'$2000',
#  u'$32000',
#  u'$32000',
#  u'$2545',
#  u'$2545',
#  u'$1950',
#  u'$1950',
#  u'$13899',
#  u'$13899',
#  u'$13899',
#  u'$13899',
#  u'$32900',
#  u'$32900',
#  u'$150',
#  u'$150',
#  u'$2500',
#  u'$2500',
#  u'$5000',
#  u'$5000',
#  u'$125',
#  u'$125']

# %%
class CraigslistSpider(scrapy.Spider):
    name = "craigs"
    allowed_domains = ["www.craigslist.org"]
    start_urls = (
        'https://portland.craigslist.org/search/rva?hints=static',
    )

    def parse(self, response):
        # process each restaurant link
        urls = response.xpath('//span[@class="pl"]/a[@class="hdrlnk"]/@href').extract()
        for url in urls:
            absolute_url = response.urljoin(url)
            request = scrapy.Request(
                absolute_url, callback=self.parse_movie)
            yield request

    def parse_post(self, response):
        price = response.xpath(
            '//span[@class="price"]/text()').extract_first()
        name = response.xpath(
            '//span[@id="titletextonly"]/text()').extract_first()
        neighborhood = response.xpath(
            '//span[@class="postingtitletext"]/small/text()').extract()
        movie = {
            'price': price,
            'name': name,
            'neighborhood': neighborhood,
            'url': response.url}
        yield movie

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2.1 Create a mapping of cities to cooresponding regional Craigslist URLs
#
# Major US cities on Craigslist typically have their own cooresponding section (ie: SFBay Area, NYC, Boston, Miami, Seattle, etc).  Later, you will use these to query search results for various metropolitian regions listed on Craigslist.  Between the major metropolitan Craigslist sites, the only thing that will differ is the URL's that correspond to them.
#
# The point of the "mapping":  Create a data structure that allows you to iterate with both the name of the city from Wikipedia, with the cooresponding variable that that will allow you to construct each craigslist URL for each region.
#
# > For San Francsico (the Bay Area metropolitan area), the url for the RV search result is:
# > http://sfbay.craigslist.org/search/sss?query=rv
# >
# > The convention is http://[region].craigslist.org/search/sss?query=rf
# > Replacing [region] with the cooresponding city name will allow you to quickly iterate through each regional Craigslist site, and scrape the prices from the search results.  Keep this in mind while you build this "mapping".

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Define a function to caculate mean and median price per city.
#
# Now that you've created a list of cities you want to scrape, adapt your solution for grabbing data in one region site, to grab data for all regional sites that you collected, then calculate the mean and median price of RV results from each city.
#
# > Look at the URLs from a few different regions (ie: portland, phoenix, sfbay), and find what they have in common.  Determine the area in the URL string that needs to change the least, and figure out how to replace only that portion of the URL in order to iterate through each city.

# %%
response = requests.get("http://sfbay.craigslist.org/search/sss?sort=rel&query=rv")
SF = response.text
SF_price = Selector(text=SF).xpath('//span[@class="price"]/text()').extract()
SF_price = pd.DataFrame(SF_price)
SF_price['price'] = SF_price[0]
SF_price['price'] = SF_price['price'].apply(lambda x: x.replace('$', ' '))
SF_price.price.mean
# Out:
# <bound method Series.mean of 0       17999
# 1       17999
# 2       36999
# 3       36999
# 4       13999
# 5       13999
# 6       14900
# 7       14900
# 8       36999
# 9       36999
# 10       9999
# 11       9999
# 12        100
# 13        100
# 14       9999
# 15       9999
# 16      17999
# 17      17999
# 18        100
# 19        100
# 20          5
# 21          5
# 22      17999
# 23      17999
# 24      33016
# 25      33016
# 26         50
# 27         50
# 28       5000
# 29       5000
#         ...
# 112     28750
# 113     28750
# 114     16000
# 115     16000
# 116     15000
# 117     15000
# 118       145
# 119       145
# 120     10999
# 121     10999
# 122       100
# 123       100
# 124        60
# 125        60
# 126        90
# 127        90
# 128     39500
# 129     39500
# 130       700
# 131       700
# 132       200
# 133       200
# 134       230
# 135       230
# 136     15500
# 137     15500
# 138        90
# 139        90
# 140     33997
# 141     33997
# Name: price, dtype: object>

# %%
SF_price = pd.DataFrame(SF_price)
SF_price['price'] = SF_price[0]
SF_price['price'] = SF_price['price'].apply(lambda x: x.replace('$', ' '))
SF_price.price = SF_price.price.astype(float)
# Out:
# Average selling price in SanFrancisco: 18580.1971831
# Median selling price in SanFrancisco: 17999.0

# %%
portland_response = requests.get("http://portland.craigslist.org/search/sss?sort=rel&query=rv")
portland = portland_response.text
portland_price = Selector(text=portland).xpath('//span[@class="price"]/text()').extract()

# %%
portland_price = pd.DataFrame(portland_price)
portland_price['price'] = portland_price[0]
portland_price['price'] = portland_price['price'].apply(lambda x: x.replace('$', ' '))

# %%
portland_price.price = portland_price.price.astype(float)
# Out:
# Average selling price in Portland: 40933.9333333
# Median selling price in Portland: 31999.0

# %%
print 'Average selling price in SanFrancisco:', SF_price.price.mean()
print 'Median selling price in SanFrancisco:', SF_price.price.median()
print 'Average selling price in Portland:', portland_price.price.mean()
print 'Median selling price in Portland:', portland_price.price.median()
# Out:
# Average selling price in SanFrancisco: 18580.1971831
# Median selling price in SanFrancisco: 17999.0
# Average selling price in Portland: 40933.9333333
# Median selling price in Portland: 31999.0

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Run your scraping process, and save your results to a CSV file.

# %%
response = requests.get("http://www.portland.craigslist.org")
HTML = response.text  
HTML[0:150]
# Out:
# u'<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">\n<html><head>\n<title>404 Not Found</title>\n</head><body>\n<h1>Not Found</h1>\n<p>The requested URL / w'

# %%
import scrapy
class craigslist(scrapy.Spider):
    name = 'portland_rv'
    allowed_domains = ['portland.craigslist.org']
    start_urls = (
        'https://portland.craigslist.org/search/rva?hints=static',
    )

    def parse(self, response):
        urls = response.xpath('//span/a/@href').extract()
        for url in urls:
            absolute_url = response.urljoin(url)
            request = scrapy.Request(
                absolute_url, callback=self.parse_craigslist)
            yield request

        next_page_url = response.xpath('//div/span/a[@class="button next"]/@href').extract_first()
        absolute_next_page_url = response.urljoin(next_page_url)
        request = scrapy.Request(absolute_next_page_url)
        yield request

    def parse_craigslist(self, response):
        title = response.xpath(
            '//span[@class="pl"]/a[@class="hdrlnk"]').extract_first()
        price = response.xpath(
            '//span[@class="l2"]/span[@class="price"]').extract_first()
        neighborhood = response.xpath(
            '//span[@class="l2"]/span[@class="pnr"]/small').extract_first()

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Do an analysis of the RV market.
#
# Go head we'll wait.  Anything notable about the data?

# %%
import scrapy
from scrapy.spider import BaseSpider
from scrapy.selector import HtmlXPathSelector
from RV.items import RvItem

class CraigslistSpider(scrapy.Spider):
    name = "craigsRV"
    allowed_domains = ["www.craigslist.org"]
    start_urls = (
        'https://portland.craigslist.org/search/rva',
    )

    def parse(self, response):
        urls = response.xpath('//span[@class="pl"]/a[@class="hdrlnk"]/@href').extract()
        for url in urls:
            absolute_url = response.urljoin(url)
            request = scrapy.Request(
                absolute_url, callback=self.parse_post)
            yield request

        next_page_url = response.xpath(
            '//a[@class="button next"]/@href').extract()
        abs_next_page_url = response.urljoin(next_page_url)
        request = scrapy.Request(abs_next_page_url)
        yield request

    def parse_post(self, response):
        price = response.xpath(
            '//span[@class="price"]/text()').extract_first()
        name = response.xpath(
            '//span[@id="titletextonly"]/text()').extract_first()
        neighborhood = response.xpath(
            '//span[@class="postingtitletext"]/small/text()').extract()
        post = {
            'price': price,
            'name': name,
            'neighborhood': neighborhood,
            'url': response.url}
        yield movie

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.1 Does it makes sense to buy RVs in one region and sell them in another?
#
# Assuming the cost of shipping or driving from one regional market to another.

# %% [markdown]
# Average and median price of RV in portland is about twice as must as the selling prices in San Francisco. Assuming the cost of shipping/driving from San Francisco to Portland should not be more than $1,000, it may be a decent business to start buying RV in San Francisco and moving them to Portland and selling them there for a  significant profit.

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.2 Can you pull out the "make" from the markup and include that in your analyis?
# How reliable is this data and does it make sense?

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 5.3 Are there any other variables you could pull out of the markup to help describe your dataset?

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 6. Move your project into scrapy (if you haven't used Scrapy yet)
#
# >Start a project by using the command `scrapy startproject [projectname]`
# > - Update your settings.py (review our past example)
# > - Update your items.py
# > - Create a spiders file in your `[project_name]/[project_name]/spiders` directory
#
# You can update your spider class with the complete list of craigslist "start urls" to effectively scrape all of the regions.  Start with one to test.
#
# Updating your parse method with the method you chose should require minimal changes.  It will require you to update your parse method to use the response parameter, and an item model (defined in items.py).

# %% [markdown]
# <img src="http://imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7.  Chose another area of Craigslist to scrape.
#
# **Choose an area having more than a single page of results, then scrape multiple regions, multiple pages of search results and or details pages.**
#
# This is the true exercise of being able to understand how to succesffuly plan, develop, and employ a broader scraping strategy.  Even though this seems like a challenging task, a few tweeks of your current code can make this very managable if you've pieced together all the touch points.  If you are still confused as to some of the milestones within this process, this is an excellent opportunity to round out your understanding, or help you build a list of questions to fill in your gaps.
#
# _Use Scrapy!  Provide your code in this project directory when you submit this project._

# %% [markdown]
# ## Optional: Interview Questions
#
# ----
#
# ### SQL Practice
#
# 1)
# We have a deliveries table with 3000 rows
#
# `SELECT * FROM deliveries;
# -- 3000 rows in set (0.05 sec) `
#
# 15 of those orders are from a customer with the customer_id_number=32
#
# `SELECT * FROM deliveries WHERE customer_id_number = 32;
# -- 15 rows in set (0.10 sec)`
#
# Yet, when we SELECT the number of orders that are not from customer_id_number = 32, we only get 2960 results:
#
# `SELECT * FROM deliveries WHERE customer_id_number <> 32;
# -- 2960 rows in set (0.11 sec)`
#
# **Question: What’s wrong? And why might this be the case? Modify your code to fix this. **
#
# 2) Construct the following tables:
#
# `mysql> SELECT * FROM Employee;
# +--------+----------+--------+
# | emp_id | emp_name | salary |
# +--------+----------+--------+
# | 1      | James    |   2000 |
# | 2      | Jack     |   4000 |
# | 3      | Henry    |   6000 |
# | 4      | Tom      |   8000 |
# +--------+----------+--------+
# 4 rows IN SET (0.00 sec)`
#
#
# `mysql> SELECT * FROM Department;
# +---------+-----------+
# | dept_id | dept_name |
# +---------+-----------+
# | 101     | Sales     |
# | 102     | Marketing |
# | 103     | Finance   |
# | 104     | Accounting   |
# +---------+-----------+
# 3 rows IN SET (0.00 sec)`
#
#
# `mysql> SELECT * FROM Register;
# +--------+---------+
# | emp_id | dept_id |
# +--------+---------+
# |      1 |     101 |
# |      2 |     102 |
# |      3 |     103 |
# |      4 |     102 |
# +--------+---------+
# 4 rows IN SET (0.00 sec)`
#
# ** Questions: **
# - Which employees belong to which department? Show this using one line of code (hint: more than one join)
# - What is the total marketing salary?
# - Using a join, can you show that there are no employees in accounting?
#
#
#
# 3) Given an Employee table which has 3 fields – Id (Primary key), Salary and Manager Id, where manager id is the id of the employee that manages the current employee, find all employees that make more than their manager in terms of salary. Create the table and write the code that finds this
#
#
# ---
# ### Predictive Modeling
#
# - What are some differences you would expect in a regression model that minimizes squared error, versus a model that minimizes absolute error? In which cases would each error  metric be appropriate?
#
# - What error metric would you use to evaluate how good a binary classifier is? What if the classes are imbalanced?  What if there are more than 2 groups?
#
# - What are various ways to predict a binary response variable? Can you compare two of them and tell me when one would be more appropriate? What’s the difference logistic regression and SVMs?
#
# - What is the difference between the loss functions used by SVMs and Logistic Regression?
#
# - What is R-squared? What are some other metrics that could be better than R-squared and why?
#
# - You run your regression on different subsets of your data, and find that in each subset, the beta value for a certain variable varies wildly. What could be the issue here?
#
#
# ---
# ### Coding Questions
#
# - Given a sorted array and a number x, find a pair in array whose sum is closest to x. What is the time complexity of your algorithm?
#
#     `Examples:`
#         Input: arr[] = {10, 22, 28, 29, 30, 40}, x = 54
#         Output: 22 and 30
#
#         Input: arr[] = {1, 3, 4, 7, 10}, x = 15
#         Output: 4 and 10
#
# - Check out this video on Linear Time Algorithm for finding the median: https://www.youtube.com/watch?v=_xntajCBLoE. Implement your version of this algorithm in Python.
#
# - Search in an almost sorted array: Given an array which is sorted, but after sorting some elements are moved to either of the adjacent positions, i.e., arr[i] may be present at arr[i+1] or arr[i-1]. Write an efficient function to search an element in this array. Basically the element arr[i] can only be swapped with either arr[i+1] or arr[i-1]. For example consider the array {2, 3, 10, 4, 40}, 4 is moved to next position and 10 is moved to previous position. [Hint: You can do this O(log n) time complexity]
#
#     `Examples: `
#         Input: arr[] =  {10, 3, 40, 20, 50, 80, 70}, key = 40
#         Output: 2
#         Output is index of 40 in given array
#
#         Input: arr[] =  {10, 3, 40, 20, 50, 80, 70}, key = 90
#         Output: -1
#         -1 is returned to indicate element is not present
